# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import the Libraries
from scipy.io import arff
import pandas as pd

#Load the data using "arff.loadarff" then convert it to dataframe
data = arff.loadarff('/content/1year.arff')
data = pd.DataFrame(data[0])

# %%
data
# Out:
#          Attr1    Attr2    Attr3    Attr4     Attr5     Attr6     Attr7  \
# 0     0.200550  0.37951  0.39641  2.04720   32.3510  0.388250  0.249760
# 1     0.209120  0.49988  0.47225  1.94470   14.7860  0.000000  0.258340
# 2     0.248660  0.69592  0.26713  1.55480   -1.1523  0.000000  0.309060
# 3     0.081483  0.30734  0.45879  2.49280   51.9520  0.149880  0.092704
# 4     0.187320  0.61323  0.22960  1.40630   -7.3128  0.187320  0.187320
# ...        ...      ...      ...      ...       ...       ...       ...
# 7022  0.018371  0.47410 -0.13619  0.60839  -18.4490  0.018371  0.018371
# 7023 -0.013359  0.58354 -0.02265  0.92896  -42.2320 -0.013359 -0.015036
# 7024  0.006338  0.50276  0.43923  1.87360    9.7417  0.006338  0.012022
# 7025 -0.041643  0.84810 -0.12852  0.57485 -121.9200  0.000000 -0.036795
# 7026  0.014946  0.94648  0.03211  1.03630  -20.5810  0.000000  0.015260
#
#          Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# 0     1.330500  1.13890  0.504940  ...  0.121960  0.397180  0.87804  0.001924
# 1     0.996010  1.69960  0.497880  ...  0.121300  0.420020  0.85300  0.000000
# 2     0.436950  1.30900  0.304080  ...  0.241140  0.817740  0.76599  0.694840
# 3     1.866100  1.05710  0.573530  ...  0.054015  0.142070  0.94598  0.000000
# 4     0.630700  1.15590  0.386770  ...  0.134850  0.484310  0.86515  0.124440
# ...        ...      ...       ...  ...       ...       ...      ...       ...
# 7022  0.972030  1.01210  0.460840  ...  0.011909  0.039866  0.98809  0.274140
# 7023  0.562890  0.98904  0.328470  ... -0.011082 -0.040671  1.01110  0.805920
# 7024  0.983560  1.00830  0.494490  ...  0.008258  0.012817  0.99174  0.000000
# 7025  0.179010  0.42138  0.151820  ... -0.232720 -0.274290  0.98788  3.593100
# 7026  0.056357  2.96940  0.053341  ...  0.015705  0.280210  0.97443  1.179200
#
#        Attr60   Attr61   Attr62   Attr63    Attr64  class
# 0      8.4160   5.1372   82.658   4.4158   7.42770   b'0'
# 1      4.1486   3.2732  107.350   3.4000  60.98700   b'0'
# 2      4.9909   3.9510  134.270   2.7185   5.20780   b'0'
# 3      4.5746   3.6147   86.435   4.2228   5.54970   b'0'
# 4      6.3985   4.3158  127.210   2.8692   7.89800   b'0'
# ...       ...      ...      ...      ...       ...    ...
# 7022  73.5050  79.2370   31.268  11.6730   5.14890   b'1'
# 7023  10.5990   7.1740   94.092   3.8792   1.75720   b'1'
# 7024  10.4700   6.0759   51.019   7.1542  62.00100   b'1'
# 7025  39.7030   3.1420  261.850   1.3939   0.51005   b'1'
# 7026  15.0360   4.1741  108.640   3.3599  35.11800   b'1'
#
# [7027 rows x 65 columns]

# %%
data.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0  1.1389  0.50494  ...  0.121960  0.39718  0.87804  0.001924  8.4160  5.1372
# 1  1.6996  0.49788  ...  0.121300  0.42002  0.85300  0.000000  4.1486  3.2732
# 2  1.3090  0.30408  ...  0.241140  0.81774  0.76599  0.694840  4.9909  3.9510
# 3  1.0571  0.57353  ...  0.054015  0.14207  0.94598  0.000000  4.5746  3.6147
# 4  1.1559  0.38677  ...  0.134850  0.48431  0.86515  0.124440  6.3985  4.3158
#
#     Attr62  Attr63   Attr64  class
# 0   82.658  4.4158   7.4277   b'0'
# 1  107.350  3.4000  60.9870   b'0'
# 2  134.270  2.7185   5.2078   b'0'
# 3   86.435  4.2228   5.5497   b'0'
# 4  127.210  2.8692   7.8980   b'0'
#
# [5 rows x 65 columns]

# %%
data.tail()
# Out:
#          Attr1    Attr2    Attr3    Attr4     Attr5     Attr6     Attr7  \
# 7022  0.018371  0.47410 -0.13619  0.60839  -18.4490  0.018371  0.018371
# 7023 -0.013359  0.58354 -0.02265  0.92896  -42.2320 -0.013359 -0.015036
# 7024  0.006338  0.50276  0.43923  1.87360    9.7417  0.006338  0.012022
# 7025 -0.041643  0.84810 -0.12852  0.57485 -121.9200  0.000000 -0.036795
# 7026  0.014946  0.94648  0.03211  1.03630  -20.5810  0.000000  0.015260
#
#          Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58   Attr59  \
# 7022  0.972030  1.01210  0.460840  ...  0.011909  0.039866  0.98809  0.27414
# 7023  0.562890  0.98904  0.328470  ... -0.011082 -0.040671  1.01110  0.80592
# 7024  0.983560  1.00830  0.494490  ...  0.008258  0.012817  0.99174  0.00000
# 7025  0.179010  0.42138  0.151820  ... -0.232720 -0.274290  0.98788  3.59310
# 7026  0.056357  2.96940  0.053341  ...  0.015705  0.280210  0.97443  1.17920
#
#       Attr60   Attr61   Attr62   Attr63    Attr64  class
# 7022  73.505  79.2370   31.268  11.6730   5.14890   b'1'
# 7023  10.599   7.1740   94.092   3.8792   1.75720   b'1'
# 7024  10.470   6.0759   51.019   7.1542  62.00100   b'1'
# 7025  39.703   3.1420  261.850   1.3939   0.51005   b'1'
# 7026  15.036   4.1741  108.640   3.3599  35.11800   b'1'
#
# [5 rows x 65 columns]

# %%
data_keys= list(data.keys())
len(data_keys)
# Out:
# 65

# %%
print(data.shape)
# Out:
# (7027, 65)

# %%
data.describe()
# Out:
#              Attr1        Attr2        Attr3        Attr4         Attr5  \
# count  7024.000000  7024.000000  7024.000000  6997.000000  7.019000e+03
# mean      0.034660     0.560215     0.119969     2.629143 -2.631672e+02
# std       4.565504     5.350084     5.275459    13.257356  3.707460e+04
# min    -256.890000   -72.162000  -440.500000     0.000000 -2.722100e+06
# 25%       0.021182     0.296678     0.026968     1.063100 -4.449800e+01
# 50%       0.075802     0.482960     0.181275     1.502000 -5.373900e+00
# 75%       0.160268     0.680233     0.362548     2.460700  3.777050e+01
# max      94.280000   441.500000     1.000000  1017.800000  9.909000e+05
#
#              Attr6        Attr7        Attr8        Attr9       Attr10  ...  \
# count  7024.000000  7024.000000  7002.000000  7026.000000  7024.000000  ...
# mean      0.059712     0.313876     2.623996     5.552855     1.825832  ...
# std       6.051113     8.353274    18.708327   101.995448    33.836452  ...
# min    -397.890000  -189.560000  -141.410000     0.000005  -440.550000  ...
# 25%       0.000000     0.028023     0.445710     1.037225     0.300785  ...
# 50%       0.000000     0.090109     1.015100     1.205750     0.492235  ...
# 75%       0.146660     0.188667     2.267675     2.132975     0.675677  ...
# max     303.670000   453.770000  1452.200000  3876.100000  1099.500000  ...
#
#              Attr55        Attr56       Attr57        Attr58       Attr59  \
# count  7.027000e+03  7.027000e+03  7026.000000  7.027000e+03  7026.000000
# mean   8.855693e+03 -1.577367e+02     0.193243  1.587409e+02     0.277829
# std    7.247527e+04  1.322125e+04     4.344046  1.322124e+04     6.339149
# min   -8.004700e+05 -1.108300e+06  -315.370000 -4.194000e-03  -327.970000
# 25%    9.712000e+01  2.031450e-02     0.056772  8.647650e-01     0.000000
# 50%    1.604800e+03  6.338200e-02     0.175745  9.388100e-01     0.028438
# 75%    5.955900e+03  1.376950e-01     0.351922  9.820150e-01     0.273867
# max    4.398400e+06  1.000000e+00   126.670000  1.108300e+06   119.580000
#
#              Attr60        Attr61        Attr62       Attr63         Attr64
# count  6.892000e+03   7005.000000  7.027000e+03  6997.000000    6993.000000
# mean   4.328830e+02     15.642228  4.763202e+03     8.126852     208.731950
# std    2.612802e+04    261.554534  3.107835e+05    19.996419    5140.708804
# min    4.700000e-05      0.000016  0.000000e+00     0.000015       0.000010
# 25%    5.923950e+00      4.829000  4.322250e+01     3.425400       2.538600
# 50%    1.004050e+01      7.033700  6.850900e+01     5.303200       4.637700
# 75%    2.013900e+01     10.703000  1.063350e+02     8.357900       9.782200
# max    2.137800e+06  21110.000000  2.501600e+07  1042.200000  294770.000000
#
# [8 rows x 64 columns]

# %%
data.describe().transpose()
# Out:
#          count         mean            std           min        25%  \
# Attr1   7024.0     0.034660       4.565504 -2.568900e+02   0.021182
# Attr2   7024.0     0.560215       5.350084 -7.216200e+01   0.296678
# Attr3   7024.0     0.119969       5.275459 -4.405000e+02   0.026968
# Attr4   6997.0     2.629143      13.257356  0.000000e+00   1.063100
# Attr5   7019.0  -263.167247   37074.596449 -2.722100e+06 -44.498000
# ...        ...          ...            ...           ...        ...
# Attr60  6892.0   432.882958   26128.019222  4.700000e-05   5.923950
# Attr61  7005.0    15.642228     261.554534  1.600000e-05   4.829000
# Attr62  7027.0  4763.201955  310783.483587  0.000000e+00  43.222500
# Attr63  6997.0     8.126852      19.996419  1.500000e-05   3.425400
# Attr64  6993.0   208.731950    5140.708804  1.000000e-05   2.538600
#
#               50%         75%          max
# Attr1    0.075802    0.160268        94.28
# Attr2    0.482960    0.680233       441.50
# Attr3    0.181275    0.362548         1.00
# Attr4    1.502000    2.460700      1017.80
# Attr5   -5.373900   37.770500    990900.00
# ...           ...         ...          ...
# Attr60  10.040500   20.139000   2137800.00
# Attr61   7.033700   10.703000     21110.00
# Attr62  68.509000  106.335000  25016000.00
# Attr63   5.303200    8.357900      1042.20
# Attr64   4.637700    9.782200    294770.00
#
# [64 rows x 8 columns]

# %%
data.corr()
# Out:
# <ipython-input-10-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#            Attr1     Attr2     Attr3     Attr4     Attr5     Attr6     Attr7  \
# Attr1   1.000000 -0.155932  0.159913  0.014650  0.008364  0.129868  0.422068
# Attr2  -0.155932  1.000000 -0.985782 -0.010019 -0.052235 -0.772227 -0.193355
# Attr3   0.159913 -0.985782  1.000000  0.011219  0.052916  0.781194  0.087043
# Attr4   0.014650 -0.010019  0.011219  1.000000 -0.000885  0.003946  0.014725
# Attr5   0.008364 -0.052235  0.052916 -0.000885  1.000000  0.040984  0.004792
# ...          ...       ...       ...       ...       ...       ...       ...
# Attr60 -0.000375 -0.000016 -0.000332 -0.003344 -0.000193 -0.000172 -0.000775
# Attr61  0.009186 -0.002368 -0.001286 -0.003024 -0.000168  0.001205  0.200103
# Attr62 -0.000848  0.005456 -0.005054 -0.001617 -0.002224 -0.003916 -0.000973
# Attr63  0.049427 -0.017961  0.016156  0.259509  0.005443  0.008937  0.074479
# Attr64 -0.041161 -0.104069 -0.018111 -0.002469  0.000218  0.075933  0.193554
#
#            Attr8     Attr9    Attr10  ...    Attr55    Attr56    Attr57  \
# Attr1   0.016007 -0.561939 -0.349011  ...  0.002983  0.000061  0.004398
# Attr2  -0.008612 -0.073338 -0.221383  ... -0.009709 -0.000655 -0.000743
# Attr3   0.007717 -0.000664  0.155591  ...  0.010827  0.000019  0.002130
# Attr4   0.191945 -0.013729  0.009601  ...  0.021739  0.001198  0.001944
# Attr5   0.002115  0.003074  0.008561  ...  0.002832 -0.000091  0.000274
# ...          ...       ...       ...  ...       ...       ...       ...
# Attr60 -0.002146 -0.000539 -0.000679  ... -0.001490  0.000200 -0.001211
# Attr61  0.013407  0.361653  0.246368  ... -0.003867  0.000716  0.001100
# Attr62 -0.001838 -0.000829 -0.001491  ... -0.005743 -0.960360 -0.000528
# Attr63  0.492540  0.221595  0.044757  ...  0.010697  0.004864  0.009670
# Attr64 -0.066054  0.255474  0.322211  ... -0.004461  0.000486 -0.001642
#
#           Attr58    Attr59    Attr60    Attr61    Attr62    Attr63    Attr64
# Attr1  -0.000061  0.000287 -0.000375  0.009186 -0.000848  0.049427 -0.041161
# Attr2   0.000656  0.000979 -0.000016 -0.002368  0.005456 -0.017961 -0.104069
# Attr3  -0.000019 -0.001116 -0.000332 -0.001286 -0.005054  0.016156 -0.018111
# Attr4  -0.001198 -0.005648 -0.003344 -0.003024 -0.001617  0.259509 -0.002469
# Attr5   0.000091  0.004470 -0.000193 -0.000168 -0.002224  0.005443  0.000218
# ...          ...       ...       ...       ...       ...       ...       ...
# Attr60 -0.000200 -0.000674  1.000000 -0.000576 -0.000248 -0.001551 -0.000581
# Attr61 -0.000716 -0.001566 -0.000576  1.000000 -0.000907  0.180655  0.954745
# Attr62  0.960360  0.005322 -0.000248 -0.000907  1.000000 -0.006185 -0.000619
# Attr63 -0.004864 -0.011145 -0.001551  0.180655 -0.006185  1.000000  0.179843
# Attr64 -0.000486 -0.001674 -0.000581  0.954745 -0.000619  0.179843  1.000000
#
# [64 rows x 64 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7027 entries, 0 to 7026
# Data columns (total 65 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Attr1   7024 non-null   float64
#  1   Attr2   7024 non-null   float64
#  2   Attr3   7024 non-null   float64
#  3   Attr4   6997 non-null   float64
#  4   Attr5   7019 non-null   float64
#  5   Attr6   7024 non-null   float64
#  6   Attr7   7024 non-null   float64
#  7   Attr8   7002 non-null   float64
#  8   Attr9   7026 non-null   float64
#  9   Attr10  7024 non-null   float64
#  10  Attr11  6988 non-null   float64
#  11  Attr12  6997 non-null   float64
#  12  Attr13  7027 non-null   float64
#  13  Attr14  7024 non-null   float64
#  14  Attr15  7025 non-null   float64
#  15  Attr16  7002 non-null   float64
#  16  Attr17  7002 non-null   float64
#  17  Attr18  7024 non-null   float64
#  18  Attr19  7027 non-null   float64
#  19  Attr20  7027 non-null   float64
#  20  Attr21  5405 non-null   float64
#  21  Attr22  7024 non-null   float64
#  22  Attr23  7027 non-null   float64
#  23  Attr24  6903 non-null   float64
#  24  Attr25  7024 non-null   float64
#  25  Attr26  7002 non-null   float64
#  26  Attr27  6716 non-null   float64
#  27  Attr28  6993 non-null   float64
#  28  Attr29  7024 non-null   float64
#  29  Attr30  7027 non-null   float64
#  30  Attr31  7027 non-null   float64
#  31  Attr32  6989 non-null   float64
#  32  Attr33  6997 non-null   float64
#  33  Attr34  7002 non-null   float64
#  34  Attr35  7024 non-null   float64
#  35  Attr36  7024 non-null   float64
#  36  Attr37  4287 non-null   float64
#  37  Attr38  7024 non-null   float64
#  38  Attr39  7027 non-null   float64
#  39  Attr40  6997 non-null   float64
#  40  Attr41  6943 non-null   float64
#  41  Attr42  7027 non-null   float64
#  42  Attr43  7027 non-null   float64
#  43  Attr44  7027 non-null   float64
#  44  Attr45  6893 non-null   float64
#  45  Attr46  6996 non-null   float64
#  46  Attr47  6998 non-null   float64
#  47  Attr48  7024 non-null   float64
#  48  Attr49  7027 non-null   float64
#  49  Attr50  7002 non-null   float64
#  50  Attr51  7024 non-null   float64
#  51  Attr52  6998 non-null   float64
#  52  Attr53  6993 non-null   float64
#  53  Attr54  6993 non-null   float64
#  54  Attr55  7027 non-null   float64
#  55  Attr56  7027 non-null   float64
#  56  Attr57  7026 non-null   float64
#  57  Attr58  7027 non-null   float64
#  58  Attr59  7026 non-null   float64
#  59  Attr60  6892 non-null   float64
#  60  Attr61  7005 non-null   float64
#  61  Attr62  7027 non-null   float64
#  62  Attr63  6997 non-null   float64
#  63  Attr64  6993 non-null   float64
#  64  class   7027 non-null   object
# dtypes: float64(64), object(1)
# memory usage: 3.5+ MB

# %%
data.columns
# Out:
# Index(['Attr1', 'Attr2', 'Attr3', 'Attr4', 'Attr5', 'Attr6', 'Attr7', 'Attr8',
#        'Attr9', 'Attr10', 'Attr11', 'Attr12', 'Attr13', 'Attr14', 'Attr15',
#        'Attr16', 'Attr17', 'Attr18', 'Attr19', 'Attr20', 'Attr21', 'Attr22',
#        'Attr23', 'Attr24', 'Attr25', 'Attr26', 'Attr27', 'Attr28', 'Attr29',
#        'Attr30', 'Attr31', 'Attr32', 'Attr33', 'Attr34', 'Attr35', 'Attr36',
#        'Attr37', 'Attr38', 'Attr39', 'Attr40', 'Attr41', 'Attr42', 'Attr43',
#        'Attr44', 'Attr45', 'Attr46', 'Attr47', 'Attr48', 'Attr49', 'Attr50',
#        'Attr51', 'Attr52', 'Attr53', 'Attr54', 'Attr55', 'Attr56', 'Attr57',
#        'Attr58', 'Attr59', 'Attr60', 'Attr61', 'Attr62', 'Attr63', 'Attr64',
#        'class'],
#       dtype='object')

# %%
data['class'].value_counts()
# Out:
# b'0'    6756
# b'1'     271
# Name: class, dtype: int64

# %%
data.isna().sum()
# Out:
# Attr1      3
# Attr2      3
# Attr3      3
# Attr4     30
# Attr5      8
#           ..
# Attr61    22
# Attr62     0
# Attr63    30
# Attr64    34
# class      0
# Length: 65, dtype: int64

# %%
data.hist( figsize=(18,18))
# Out:
# array([[<Axes: title={'center': 'Attr1'}>,
#         <Axes: title={'center': 'Attr2'}>,
#         <Axes: title={'center': 'Attr3'}>,
#         <Axes: title={'center': 'Attr4'}>,
#         <Axes: title={'center': 'Attr5'}>,
#         <Axes: title={'center': 'Attr6'}>,
#         <Axes: title={'center': 'Attr7'}>,
#         <Axes: title={'center': 'Attr8'}>],
#        [<Axes: title={'center': 'Attr9'}>,
#         <Axes: title={'center': 'Attr10'}>,
#         <Axes: title={'center': 'Attr11'}>,
#         <Axes: title={'center': 'Attr12'}>,
#         <Axes: title={'center': 'Attr13'}>,
#         <Axes: title={'center': 'Attr14'}>,
#         <Axes: title={'center': 'Attr15'}>,
#         <Axes: title={'center': 'Attr16'}>],
#        [<Axes: title={'center': 'Attr17'}>,
#         <Axes: title={'center': 'Attr18'}>,
#         <Axes: title={'center': 'Attr19'}>,
#         <Axes: title={'center': 'Attr20'}>,
#         <Axes: title={'center': 'Attr21'}>,
#         <Axes: title={'center': 'Attr22'}>,
#         <Axes: title={'center': 'Attr23'}>,
#         <Axes: title={'center': 'Attr24'}>],
#        [<Axes: title={'center': 'Attr25'}>,
#         <Axes: title={'center': 'Attr26'}>,
#         <Axes: title={'center': 'Attr27'}>,
#         <Axes: title={'center': 'Attr28'}>,
#         <Axes: title={'center': 'Attr29'}>,
#         <Axes: title={'center': 'Attr30'}>,
#         <Axes: title={'center': 'Attr31'}>,
#         <Axes: title={'center': 'Attr32'}>],
#        [<Axes: title={'center': 'Attr33'}>,
#         <Axes: title={'center': 'Attr34'}>,
#         <Axes: title={'center': 'Attr35'}>,
#         <Axes: title={'center': 'Attr36'}>,
#         <Axes: title={'center': 'Attr37'}>,
#         <Axes: title={'center': 'Attr38'}>,
#         <Axes: title={'center': 'Attr39'}>,
#         <Axes: title={'center': 'Attr40'}>],
#        [<Axes: title={'center': 'Attr41'}>,
#         <Axes: title={'center': 'Attr42'}>,
#         <Axes: title={'center': 'Attr43'}>,
#         <Axes: title={'center': 'Attr44'}>,
#         <Axes: title={'center': 'Attr45'}>,
#         <Axes: title={'center': 'Attr46'}>,
#         <Axes: title={'center': 'Attr47'}>,
#         <Axes: title={'center': 'Attr48'}>],
#        [<Axes: title={'center': 'Attr49'}>,
#         <Axes: title={'center': 'Attr50'}>,
#         <Axes: title={'center': 'Attr51'}>,
#         <Axes: title={'center': 'Attr52'}>,
#         <Axes: title={'center': 'Attr53'}>,
#         <Axes: title={'center': 'Attr54'}>,
#         <Axes: title={'center': 'Attr55'}>,
#         <Axes: title={'center': 'Attr56'}>],
#        [<Axes: title={'center': 'Attr57'}>,
#         <Axes: title={'center': 'Attr58'}>,
#         <Axes: title={'center': 'Attr59'}>,
#         <Axes: title={'center': 'Attr60'}>,
#         <Axes: title={'center': 'Attr61'}>,
#         <Axes: title={'center': 'Attr62'}>,
#         <Axes: title={'center': 'Attr63'}>,
#         <Axes: title={'center': 'Attr64'}>]], dtype=object)

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
data['class']= label_encoder.fit_transform(data['class'])

data['class'].unique()
# Out:
# array([0, 1])

# %%
data['class'].value_counts() #verify => SAME AS BEFORE
# Out:
# 0    6756
# 1     271
# Name: class, dtype: int64

# %% [markdown]
# EDA

# %%
total_cells= np.product(data.shape)
total_missing=data.isnull().sum().sum()
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 1.2774901205241322

# %%
import missingno as msno
msno.matrix(data)
# Out:
# <Axes: >

# %%
fig, axe = plt.subplots(figsize=(30,20))
msno.heatmap(data,ax=axe)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(50,60))
pltmv=sns.displot(data=data.isna().melt(value_name="missing"),
            y="variable",hue="missing",
            multiple="fill",height=10,aspect=1)
plt.savefig("visualizing_missing_data_with_barplot.png", dpi=100)

# %% [markdown]
# METHOD 1 Solving -MISSING VALUE

# %%
d1= data.copy()

# %%
data['Attr1'] = data['Attr1'].fillna(data['Attr1'].mode().iloc[0])

# %%
# Assuming 'data' is your DataFrame containing the columns 'Attr1' to 'Attr64'

for i in range(1, 65):  # Assuming the columns are named from 'Attr1' to 'Attr64'
    col_name = f'Attr{i}'
    data[col_name] = data[col_name].fillna(data[col_name].mode().iloc[0])

# %%
data.isna().sum()
# Out:
# Attr1     0
# Attr2     0
# Attr3     0
# Attr4     0
# Attr5     0
#          ..
# Attr61    0
# Attr62    0
# Attr63    0
# Attr64    0
# class     0
# Length: 65, dtype: int64

# %%
d1.describe()
# Out:
#              Attr1        Attr2        Attr3        Attr4         Attr5  \
# count  7024.000000  7024.000000  7024.000000  6997.000000  7.019000e+03
# mean      0.034660     0.560215     0.119969     2.629143 -2.631672e+02
# std       4.565504     5.350084     5.275459    13.257356  3.707460e+04
# min    -256.890000   -72.162000  -440.500000     0.000000 -2.722100e+06
# 25%       0.021182     0.296678     0.026968     1.063100 -4.449800e+01
# 50%       0.075802     0.482960     0.181275     1.502000 -5.373900e+00
# 75%       0.160268     0.680233     0.362548     2.460700  3.777050e+01
# max      94.280000   441.500000     1.000000  1017.800000  9.909000e+05
#
#              Attr6        Attr7        Attr8        Attr9       Attr10  ...  \
# count  7024.000000  7024.000000  7002.000000  7026.000000  7024.000000  ...
# mean      0.059712     0.313876     2.623996     5.552855     1.825832  ...
# std       6.051113     8.353274    18.708327   101.995448    33.836452  ...
# min    -397.890000  -189.560000  -141.410000     0.000005  -440.550000  ...
# 25%       0.000000     0.028023     0.445710     1.037225     0.300785  ...
# 50%       0.000000     0.090109     1.015100     1.205750     0.492235  ...
# 75%       0.146660     0.188667     2.267675     2.132975     0.675677  ...
# max     303.670000   453.770000  1452.200000  3876.100000  1099.500000  ...
#
#              Attr56       Attr57        Attr58       Attr59        Attr60  \
# count  7.027000e+03  7026.000000  7.027000e+03  7026.000000  6.892000e+03
# mean  -1.577367e+02     0.193243  1.587409e+02     0.277829  4.328830e+02
# std    1.322125e+04     4.344046  1.322124e+04     6.339149  2.612802e+04
# min   -1.108300e+06  -315.370000 -4.194000e-03  -327.970000  4.700000e-05
# 25%    2.031450e-02     0.056772  8.647650e-01     0.000000  5.923950e+00
# 50%    6.338200e-02     0.175745  9.388100e-01     0.028438  1.004050e+01
# 75%    1.376950e-01     0.351922  9.820150e-01     0.273867  2.013900e+01
# max    1.000000e+00   126.670000  1.108300e+06   119.580000  2.137800e+06
#
#              Attr61        Attr62       Attr63         Attr64        class
# count   7005.000000  7.027000e+03  6997.000000    6993.000000  7027.000000
# mean      15.642228  4.763202e+03     8.126852     208.731950     0.038566
# std      261.554534  3.107835e+05    19.996419    5140.708804     0.192571
# min        0.000016  0.000000e+00     0.000015       0.000010     0.000000
# 25%        4.829000  4.322250e+01     3.425400       2.538600     0.000000
# 50%        7.033700  6.850900e+01     5.303200       4.637700     0.000000
# 75%       10.703000  1.063350e+02     8.357900       9.782200     0.000000
# max    21110.000000  2.501600e+07  1042.200000  294770.000000     1.000000
#
# [8 rows x 65 columns]

# %%
sns.countplot(x=d1['class'])
plt.title('Target feature - Bankrupt class')
# Out:
# Text(0.5, 1.0, 'Target feature - Bankrupt class')

# %% [markdown]
# There is imbalance in the Target value, we need to oversample it based

# %% [markdown]
# OverSamppling :SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
from imblearn.over_sampling import SMOTE
import pandas as pd

# Assuming 'data' is your DataFrame with 'Attr1' to 'Attr64' and 'Target' column
X = data.drop('class', axis=1)
y = data['class']

# Initialize the SMOTE object
smote = SMOTE()

# Perform SMOTE oversampling
X_resampled, y_resampled = smote.fit_resample(X, y)

# Combine the resampled features and target back into a DataFrame
resampled_data = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='class')], axis=1)

# %%
X=d1.drop(labels=['class'], axis=1)
y=d1['class']

# %%
from sklearn.impute import SimpleImputer
# Assuming 'data' is your DataFrame with 'Attr1' to 'Attr64' and 'Target' column
X = data.drop('class', axis=1)
y = data['class']

# Step 1: Handle missing values using SimpleImputer
imputer = SimpleImputer(strategy='mean')  # You can choose different imputation strategies based on your data
X_imputed = imputer.fit_transform(X)

# Step 2: Apply SMOTE to oversample the target variable
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X_imputed, y)

# Combine the resampled features and target back into a DataFrame
resampled_data = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='class')], axis=1)

# %%
oversample = SMOTE()
X,y=oversample.fit_resample(X,y)

# %%
sns.countplot(x=y)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
data_x= pd.DataFrame(X,columns=data_keys[:len(data_keys)-1])
print(data_x.head())
#y class data
data_x.shape
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...    Attr55    Attr56   Attr57   Attr58    Attr59  \
# 0  1.1389  0.50494  ...  348690.0  0.121960  0.39718  0.87804  0.001924
# 1  1.6996  0.49788  ...    2304.6  0.121300  0.42002  0.85300  0.000000
# 2  1.3090  0.30408  ...    6332.7  0.241140  0.81774  0.76599  0.694840
# 3  1.0571  0.57353  ...   20545.0  0.054015  0.14207  0.94598  0.000000
# 4  1.1559  0.38677  ...    3186.6  0.134850  0.48431  0.86515  0.124440
#
#    Attr60  Attr61   Attr62  Attr63   Attr64
# 0  8.4160  5.1372   82.658  4.4158   7.4277
# 1  4.1486  3.2732  107.350  3.4000  60.9870
# 2  4.9909  3.9510  134.270  2.7185   5.2078
# 3  4.5746  3.6147   86.435  4.2228   5.5497
# 4  6.3985  4.3158  127.210  2.8692   7.8980
#
# [5 rows x 64 columns]
# (13512, 64)

# %%
data.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0  1.1389  0.50494  ...  0.121960  0.39718  0.87804  0.001924  8.4160  5.1372
# 1  1.6996  0.49788  ...  0.121300  0.42002  0.85300  0.000000  4.1486  3.2732
# 2  1.3090  0.30408  ...  0.241140  0.81774  0.76599  0.694840  4.9909  3.9510
# 3  1.0571  0.57353  ...  0.054015  0.14207  0.94598  0.000000  4.5746  3.6147
# 4  1.1559  0.38677  ...  0.134850  0.48431  0.86515  0.124440  6.3985  4.3158
#
#     Attr62  Attr63   Attr64  class
# 0   82.658  4.4158   7.4277      0
# 1  107.350  3.4000  60.9870      0
# 2  134.270  2.7185   5.2078      0
# 3   86.435  4.2228   5.5497      0
# 4  127.210  2.8692   7.8980      0
#
# [5 rows x 65 columns]

# %%
data.isna().sum()
# Out:
# Attr1     0
# Attr2     0
# Attr3     0
# Attr4     0
# Attr5     0
#          ..
# Attr61    0
# Attr62    0
# Attr63    0
# Attr64    0
# class     0
# Length: 65, dtype: int64

# %% [markdown]
# Outlier Detection

# %%
for i in data:
    sns.boxplot(x=data[i])
    plt.show()

# %% [markdown]
# treating of outliers may tend to loss of huge amount of data from the dataset

# %% [markdown]
# Scaling

# %%
from sklearn.preprocessing import minmax_scale

# %%
data = np.random.exponential(size=1000)

# %%
scaled_data = minmax_scale(data)

# %%
fig,ax = plt.subplots(1,2)
sns.distplot(data, ax= ax[0])
ax[0].set_title('data')
sns.distplot(scaled_data, ax= ax[1])
ax[1].set_title('Scaled Data')
# Out:
# <ipython-input-41-5590d0fdf95e>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data, ax= ax[0])
# <ipython-input-41-5590d0fdf95e>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(scaled_data, ax= ax[1])
# Text(0.5, 1.0, 'Scaled Data')

# %% [markdown]
# Normalization

# %%
from scipy import stats
from scipy.stats import boxcox

# %%
normalized_data=stats.boxcox(data)
fig, ax=plt.subplots(1,2)
sns.distplot(data,ax= ax[0])
ax[0].set_title('data')
sns.distplot(normalized_data[0], ax= ax[1])
ax[1].set_title('Normalized_data')
# Out:
# <ipython-input-43-c7eb294a7342>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax= ax[0])
# <ipython-input-43-c7eb294a7342>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normalized_data[0], ax= ax[1])
# Text(0.5, 1.0, 'Normalized_data')
