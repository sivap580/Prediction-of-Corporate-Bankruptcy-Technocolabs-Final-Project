# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import the Libraries
from scipy.io import arff
import pandas as pd

#Load the data using "arff.loadarff" then convert it to dataframe
data = arff.loadarff('/content/4year.arff')
data = pd.DataFrame(data[0])

# %%
data
# Out:
#          Attr1    Attr2     Attr3    Attr4     Attr5     Attr6     Attr7  \
# 0     0.159290  0.46240  0.077730  1.16830  -44.8530  0.467020  0.189480
# 1    -0.127430  0.46243  0.269170  1.75170    7.5970  0.000925 -0.127430
# 2     0.070488  0.23570  0.527810  3.23930  125.6800  0.163670  0.086895
# 3     0.136760  0.40538  0.315430  1.87050   19.1150  0.504970  0.136760
# 4    -0.110080  0.69793  0.188780  1.27130  -15.3440  0.000000 -0.110080
# ...        ...      ...       ...      ...       ...       ...       ...
# 9787  0.004676  0.54949  0.192810  1.38990  -39.0640  0.004676  0.013002
# 9788 -0.027610  0.60748 -0.029762  0.90591  -20.9230 -0.027610 -0.027610
# 9789 -0.238290  0.62708  0.090374  1.61250   -1.0692 -0.238290 -0.240360
# 9790  0.097188  0.75300 -0.327680  0.43850 -214.2400 -0.331300  0.104280
# 9791  0.021416  0.48678  0.148940  1.30670  -24.2820  0.021416  0.027253
#
#         Attr8    Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# 0     0.82895  1.12230  0.38330  ...  0.108990  0.415570  0.89101  0.001422
# 1     1.16250  1.29440  0.53757  ... -0.089372 -0.237040  1.06250  0.150410
# 2     2.87180  1.05740  0.67689  ...  0.054286  0.104130  0.94571  0.000000
# 3     1.45390  1.11440  0.58938  ...  0.102630  0.232030  0.89737  0.073024
# 4     0.43282  1.73500  0.30207  ...  0.439880 -0.364400  0.57153  0.000000
# ...       ...      ...      ...  ...       ...       ...      ...       ...
# 9787  0.78627  0.97093  0.43205  ... -0.029937  0.010823  1.02990  0.127190
# 9788  0.55161  1.00730  0.33509  ...  0.007198 -0.082395  0.99280  0.868910
# 9789  0.28322  0.80307  0.17760  ... -0.245220 -1.341700  1.24520  2.700100
# 9790  0.32803  0.98145  0.24700  ...  0.288240  0.393470  0.68127  0.508850
# 9791  1.05320  1.00140  0.51267  ...  0.001393  0.041773  0.99861  0.002146
#
#        Attr60   Attr61   Attr62  Attr63    Attr64  class
# 0      7.7928   4.9914  119.810  3.0465   3.05600   b'0'
# 1      5.4327   3.4629  100.970  3.6150   3.47250   b'0'
# 2      7.1070   3.3808   76.076  4.7978   4.78180   b'0'
# 3      6.1384   4.2241   88.299  4.1337   4.64840   b'0'
# 4     18.8010   2.7925  146.390  2.4934  15.03600   b'0'
# ...       ...      ...      ...     ...       ...    ...
# 9787   3.8159   3.3892  146.860  2.4854   3.93150   b'1'
# 9788  23.0280  27.1360   37.047  9.8523   4.36810   b'1'
# 9789   6.5694   4.1781   88.883  4.1065   0.79501   b'1'
# 9790   4.3246  35.5030  217.030  1.6818   1.31910   b'1'
# 9791   6.7582   4.9171   98.421  3.7085   4.92950   b'1'
#
# [9792 rows x 65 columns]

# %%
data.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5     Attr6     Attr7    Attr8  \
# 0  0.159290  0.46240  0.07773  1.1683  -44.853  0.467020  0.189480  0.82895
# 1 -0.127430  0.46243  0.26917  1.7517    7.597  0.000925 -0.127430  1.16250
# 2  0.070488  0.23570  0.52781  3.2393  125.680  0.163670  0.086895  2.87180
# 3  0.136760  0.40538  0.31543  1.8705   19.115  0.504970  0.136760  1.45390
# 4 -0.110080  0.69793  0.18878  1.2713  -15.344  0.000000 -0.110080  0.43282
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59   Attr60  \
# 0  1.1223  0.38330  ...  0.108990  0.41557  0.89101  0.001422   7.7928
# 1  1.2944  0.53757  ... -0.089372 -0.23704  1.06250  0.150410   5.4327
# 2  1.0574  0.67689  ...  0.054286  0.10413  0.94571  0.000000   7.1070
# 3  1.1144  0.58938  ...  0.102630  0.23203  0.89737  0.073024   6.1384
# 4  1.7350  0.30207  ...  0.439880 -0.36440  0.57153  0.000000  18.8010
#
#    Attr61   Attr62  Attr63   Attr64  class
# 0  4.9914  119.810  3.0465   3.0560   b'0'
# 1  3.4629  100.970  3.6150   3.4725   b'0'
# 2  3.3808   76.076  4.7978   4.7818   b'0'
# 3  4.2241   88.299  4.1337   4.6484   b'0'
# 4  2.7925  146.390  2.4934  15.0360   b'0'
#
# [5 rows x 65 columns]

# %%
data.tail()
# Out:
#          Attr1    Attr2     Attr3    Attr4     Attr5     Attr6     Attr7  \
# 9787  0.004676  0.54949  0.192810  1.38990  -39.0640  0.004676  0.013002
# 9788 -0.027610  0.60748 -0.029762  0.90591  -20.9230 -0.027610 -0.027610
# 9789 -0.238290  0.62708  0.090374  1.61250   -1.0692 -0.238290 -0.240360
# 9790  0.097188  0.75300 -0.327680  0.43850 -214.2400 -0.331300  0.104280
# 9791  0.021416  0.48678  0.148940  1.30670  -24.2820  0.021416  0.027253
#
#         Attr8    Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# 9787  0.78627  0.97093  0.43205  ... -0.029937  0.010823  1.02990  0.127190
# 9788  0.55161  1.00730  0.33509  ...  0.007198 -0.082395  0.99280  0.868910
# 9789  0.28322  0.80307  0.17760  ... -0.245220 -1.341700  1.24520  2.700100
# 9790  0.32803  0.98145  0.24700  ...  0.288240  0.393470  0.68127  0.508850
# 9791  1.05320  1.00140  0.51267  ...  0.001393  0.041773  0.99861  0.002146
#
#        Attr60   Attr61   Attr62  Attr63   Attr64  class
# 9787   3.8159   3.3892  146.860  2.4854  3.93150   b'1'
# 9788  23.0280  27.1360   37.047  9.8523  4.36810   b'1'
# 9789   6.5694   4.1781   88.883  4.1065  0.79501   b'1'
# 9790   4.3246  35.5030  217.030  1.6818  1.31910   b'1'
# 9791   6.7582   4.9171   98.421  3.7085  4.92950   b'1'
#
# [5 rows x 65 columns]

# %%
data_keys= list(data.keys())
len(data_keys)
# Out:
# 65

# %%
print(data.shape)
# Out:
# (9792, 65)

# %%
data.describe()
# Out:
#              Attr1        Attr2        Attr3         Attr4         Attr5  \
# count  9791.000000  9791.000000  9791.000000   9749.000000  9.771000e+03
# mean      0.043019     0.596404     0.130959      8.136600  6.465164e+01
# std       0.359321     4.587122     4.559074    290.647281  1.475939e+04
# min     -12.458000     0.000000  -445.910000     -0.045319 -3.794600e+05
# 25%       0.001321     0.263145     0.020377      1.047000 -5.121700e+01
# 50%       0.041364     0.467740     0.199290      1.591800 -5.557600e-02
# 75%       0.111130     0.689255     0.410670      2.880400  5.573200e+01
# max      20.482000   446.910000    22.769000  27146.000000  1.034100e+06
#
#              Attr6        Attr7         Attr8        Attr9       Attr10  ...  \
# count  9791.000000  9791.000000   9773.000000  9792.000000  9791.000000  ...
# mean     -0.059273     0.059446     19.884016     1.882296     0.389040  ...
# std       6.812754     0.533344    698.697015    17.674650     4.590299  ...
# min    -486.820000   -12.458000     -1.848200    -0.032371  -445.910000  ...
# 25%      -0.000578     0.003004      0.428300     1.006675     0.294440  ...
# 50%       0.000000     0.048820      1.088700     1.161300     0.510450  ...
# 75%       0.065322     0.126940      2.691000     1.970225     0.714290  ...
# max     322.200000    38.618000  53209.000000  1704.800000    12.602000  ...
#
#              Attr55       Attr56       Attr57       Attr58       Attr59  \
# count  9.792000e+03  9771.000000  9791.000000  9776.000000  9791.000000
# mean   7.686330e+03    -0.992263     0.035022     1.133287     0.856053
# std    7.605261e+04    77.007971     8.945365     8.038201    26.393305
# min   -7.132200e+05 -7522.100000  -597.420000   -30.892000  -284.380000
# 25%    2.184000e+01     0.003121     0.008768     0.885722     0.000000
# 50%    9.503300e+02     0.043679     0.098026     0.958305     0.002129
# 75%    4.694550e+03     0.117170     0.242680     0.996163     0.211790
# max    6.123700e+06   112.020000   226.760000   668.750000  1661.000000
#
#               Attr60         Attr61        Attr62       Attr63        Attr64
# count    9178.000000    9760.000000  9.771000e+03  9749.000000   9561.000000
# mean      118.156064      25.194430  2.015157e+03     8.660813     35.949619
# std      3230.316692    1099.260821  1.171461e+05    60.838202    483.318623
# min         0.000000     -12.656000 -1.496500e+04    -0.024390     -0.000015
# 25%         5.356325       4.267700  4.323400e+01     2.938800      2.012900
# 50%         9.482000       6.283550  7.472900e+01     4.848900      4.041600
# 75%        19.506000       9.938200  1.233450e+02     8.363800      9.413500
# max    251570.000000  108000.000000  1.077900e+07  5662.400000  21153.000000
#
# [8 rows x 64 columns]

# %%
data.describe().transpose()
# Out:
#          count         mean            std            min        25%  \
# Attr1   9791.0     0.043019       0.359321     -12.458000   0.001321
# Attr2   9791.0     0.596404       4.587122       0.000000   0.263145
# Attr3   9791.0     0.130959       4.559074    -445.910000   0.020377
# Attr4   9749.0     8.136600     290.647281      -0.045319   1.047000
# Attr5   9771.0    64.651636   14759.389477 -379460.000000 -51.217000
# ...        ...          ...            ...            ...        ...
# Attr60  9178.0   118.156064    3230.316692       0.000000   5.356325
# Attr61  9760.0    25.194430    1099.260821     -12.656000   4.267700
# Attr62  9771.0  2015.156851  117146.087675  -14965.000000  43.234000
# Attr63  9749.0     8.660813      60.838202      -0.024390   2.938800
# Attr64  9561.0    35.949619     483.318623      -0.000015   2.012900
#
#               50%         75%           max
# Attr1    0.041364    0.111130  2.048200e+01
# Attr2    0.467740    0.689255  4.469100e+02
# Attr3    0.199290    0.410670  2.276900e+01
# Attr4    1.591800    2.880400  2.714600e+04
# Attr5   -0.055576   55.732000  1.034100e+06
# ...           ...         ...           ...
# Attr60   9.482000   19.506000  2.515700e+05
# Attr61   6.283550    9.938200  1.080000e+05
# Attr62  74.729000  123.345000  1.077900e+07
# Attr63   4.848900    8.363800  5.662400e+03
# Attr64   4.041600    9.413500  2.115300e+04
#
# [64 rows x 8 columns]

# %%
data.corr()
# Out:
# <ipython-input-10-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#            Attr1     Attr2     Attr3     Attr4     Attr5     Attr6     Attr7  \
# Attr1   1.000000  0.519325 -0.532841  0.000124 -0.146045 -0.383014  0.670365
# Attr2   0.519325  1.000000 -0.990108 -0.002907 -0.261459 -0.734602  0.350262
# Attr3  -0.532841 -0.990108  1.000000  0.003749  0.262451  0.727585 -0.358360
# Attr4   0.000124 -0.002907  0.003749  1.000000  0.014300  0.000319 -0.000403
# Attr5  -0.146045 -0.261459  0.262451  0.014300  1.000000  0.191377 -0.098239
# ...          ...       ...       ...       ...       ...       ...       ...
# Attr60  0.001230 -0.007105  0.003167  0.001083  0.000144 -0.000019  0.703325
# Attr61 -0.000511 -0.001344  0.001281  0.010065  0.006003 -0.000214  0.023143
# Attr62  0.003295  0.064003 -0.064363 -0.001480 -0.022949 -0.045387  0.001661
# Attr63  0.021419 -0.007790  0.007849  0.017934  0.009940  0.002072  0.704706
# Attr64  0.026232  0.013540  0.028378 -0.001166  0.001017 -0.002181  0.076652
#
#            Attr8     Attr9    Attr10  ...    Attr55    Attr56    Attr57  \
# Attr1  -0.003285 -0.007146 -0.518880  ...  0.020139  0.005291  0.034100
# Attr2  -0.003584  0.001500 -0.999293  ... -0.009918 -0.003520 -0.000774
# Attr3   0.001133 -0.001269  0.990960  ...  0.009992  0.003200  0.000184
# Attr4   0.430936 -0.000846  0.002979  ... -0.000469 -0.001409  0.000051
# Attr5   0.007052  0.024971  0.268800  ...  0.005260  0.001023  0.000012
# ...          ...       ...       ...  ...       ...       ...       ...
# Attr60  0.001210  0.810964  0.004303  ... -0.001472  0.000389  0.000284
# Attr61  0.008277  0.031741  0.001378  ... -0.001500  0.000436  0.000178
# Attr62 -0.000597 -0.001754 -0.063916  ... -0.001912 -0.113641  0.000004
# Attr63  0.069916  0.924058  0.007930  ...  0.000171  0.001863  0.001693
# Attr64 -0.001677  0.074691 -0.011897  ... -0.000908  0.000925 -0.001575
#
#           Attr58    Attr59    Attr60    Attr61    Attr62    Attr63    Attr64
# Attr1  -0.036054 -0.007844  0.001230 -0.000511  0.003295  0.021419  0.026232
# Attr2   0.004643  0.001957 -0.007105 -0.001344  0.064003 -0.007790  0.013540
# Attr3  -0.004554 -0.000773  0.003167  0.001281 -0.064363  0.007849  0.028378
# Attr4   0.027537 -0.000945  0.001083  0.010065 -0.001480  0.017934 -0.001166
# Attr5  -0.001671  0.000351  0.000144  0.006003 -0.022949  0.009940  0.001017
# ...          ...       ...       ...       ...       ...       ...       ...
# Attr60 -0.000500 -0.000880  1.000000  0.382737 -0.000737  0.799851  0.062769
# Attr61 -0.001718 -0.000520  0.382737  1.000000 -0.000381  0.040871  0.001533
# Attr62  0.122680 -0.000531 -0.000737 -0.000381  1.000000 -0.002406 -0.001335
# Attr63 -0.003808 -0.002620  0.799851  0.040871 -0.002406  1.000000  0.070327
# Attr64 -0.002366 -0.001633  0.062769  0.001533 -0.001335  0.070327  1.000000
#
# [64 rows x 64 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9792 entries, 0 to 9791
# Data columns (total 65 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Attr1   9791 non-null   float64
#  1   Attr2   9791 non-null   float64
#  2   Attr3   9791 non-null   float64
#  3   Attr4   9749 non-null   float64
#  4   Attr5   9771 non-null   float64
#  5   Attr6   9791 non-null   float64
#  6   Attr7   9791 non-null   float64
#  7   Attr8   9773 non-null   float64
#  8   Attr9   9792 non-null   float64
#  9   Attr10  9791 non-null   float64
#  10  Attr11  9791 non-null   float64
#  11  Attr12  9749 non-null   float64
#  12  Attr13  9771 non-null   float64
#  13  Attr14  9791 non-null   float64
#  14  Attr15  9784 non-null   float64
#  15  Attr16  9773 non-null   float64
#  16  Attr17  9773 non-null   float64
#  17  Attr18  9791 non-null   float64
#  18  Attr19  9771 non-null   float64
#  19  Attr20  9771 non-null   float64
#  20  Attr21  9634 non-null   float64
#  21  Attr22  9791 non-null   float64
#  22  Attr23  9771 non-null   float64
#  23  Attr24  9581 non-null   float64
#  24  Attr25  9791 non-null   float64
#  25  Attr26  9773 non-null   float64
#  26  Attr27  9151 non-null   float64
#  27  Attr28  9561 non-null   float64
#  28  Attr29  9791 non-null   float64
#  29  Attr30  9771 non-null   float64
#  30  Attr31  9771 non-null   float64
#  31  Attr32  9696 non-null   float64
#  32  Attr33  9749 non-null   float64
#  33  Attr34  9773 non-null   float64
#  34  Attr35  9791 non-null   float64
#  35  Attr36  9791 non-null   float64
#  36  Attr37  5350 non-null   float64
#  37  Attr38  9791 non-null   float64
#  38  Attr39  9771 non-null   float64
#  39  Attr40  9749 non-null   float64
#  40  Attr41  9605 non-null   float64
#  41  Attr42  9771 non-null   float64
#  42  Attr43  9771 non-null   float64
#  43  Attr44  9771 non-null   float64
#  44  Attr45  9179 non-null   float64
#  45  Attr46  9749 non-null   float64
#  46  Attr47  9719 non-null   float64
#  47  Attr48  9791 non-null   float64
#  48  Attr49  9771 non-null   float64
#  49  Attr50  9773 non-null   float64
#  50  Attr51  9791 non-null   float64
#  51  Attr52  9716 non-null   float64
#  52  Attr53  9561 non-null   float64
#  53  Attr54  9561 non-null   float64
#  54  Attr55  9792 non-null   float64
#  55  Attr56  9771 non-null   float64
#  56  Attr57  9791 non-null   float64
#  57  Attr58  9776 non-null   float64
#  58  Attr59  9791 non-null   float64
#  59  Attr60  9178 non-null   float64
#  60  Attr61  9760 non-null   float64
#  61  Attr62  9771 non-null   float64
#  62  Attr63  9749 non-null   float64
#  63  Attr64  9561 non-null   float64
#  64  class   9792 non-null   object
# dtypes: float64(64), object(1)
# memory usage: 4.9+ MB

# %%
data.columns
# Out:
# Index(['Attr1', 'Attr2', 'Attr3', 'Attr4', 'Attr5', 'Attr6', 'Attr7', 'Attr8',
#        'Attr9', 'Attr10', 'Attr11', 'Attr12', 'Attr13', 'Attr14', 'Attr15',
#        'Attr16', 'Attr17', 'Attr18', 'Attr19', 'Attr20', 'Attr21', 'Attr22',
#        'Attr23', 'Attr24', 'Attr25', 'Attr26', 'Attr27', 'Attr28', 'Attr29',
#        'Attr30', 'Attr31', 'Attr32', 'Attr33', 'Attr34', 'Attr35', 'Attr36',
#        'Attr37', 'Attr38', 'Attr39', 'Attr40', 'Attr41', 'Attr42', 'Attr43',
#        'Attr44', 'Attr45', 'Attr46', 'Attr47', 'Attr48', 'Attr49', 'Attr50',
#        'Attr51', 'Attr52', 'Attr53', 'Attr54', 'Attr55', 'Attr56', 'Attr57',
#        'Attr58', 'Attr59', 'Attr60', 'Attr61', 'Attr62', 'Attr63', 'Attr64',
#        'class'],
#       dtype='object')

# %%
data['class'].value_counts()
# Out:
# b'0'    9277
# b'1'     515
# Name: class, dtype: int64

# %%
data.isna().sum()
# Out:
# Attr1       1
# Attr2       1
# Attr3       1
# Attr4      43
# Attr5      21
#          ...
# Attr61     32
# Attr62     21
# Attr63     43
# Attr64    231
# class       0
# Length: 65, dtype: int64

# %%
data.hist( figsize=(18,18))
# Out:
# array([[<Axes: title={'center': 'Attr1'}>,
#         <Axes: title={'center': 'Attr2'}>,
#         <Axes: title={'center': 'Attr3'}>,
#         <Axes: title={'center': 'Attr4'}>,
#         <Axes: title={'center': 'Attr5'}>,
#         <Axes: title={'center': 'Attr6'}>,
#         <Axes: title={'center': 'Attr7'}>,
#         <Axes: title={'center': 'Attr8'}>],
#        [<Axes: title={'center': 'Attr9'}>,
#         <Axes: title={'center': 'Attr10'}>,
#         <Axes: title={'center': 'Attr11'}>,
#         <Axes: title={'center': 'Attr12'}>,
#         <Axes: title={'center': 'Attr13'}>,
#         <Axes: title={'center': 'Attr14'}>,
#         <Axes: title={'center': 'Attr15'}>,
#         <Axes: title={'center': 'Attr16'}>],
#        [<Axes: title={'center': 'Attr17'}>,
#         <Axes: title={'center': 'Attr18'}>,
#         <Axes: title={'center': 'Attr19'}>,
#         <Axes: title={'center': 'Attr20'}>,
#         <Axes: title={'center': 'Attr21'}>,
#         <Axes: title={'center': 'Attr22'}>,
#         <Axes: title={'center': 'Attr23'}>,
#         <Axes: title={'center': 'Attr24'}>],
#        [<Axes: title={'center': 'Attr25'}>,
#         <Axes: title={'center': 'Attr26'}>,
#         <Axes: title={'center': 'Attr27'}>,
#         <Axes: title={'center': 'Attr28'}>,
#         <Axes: title={'center': 'Attr29'}>,
#         <Axes: title={'center': 'Attr30'}>,
#         <Axes: title={'center': 'Attr31'}>,
#         <Axes: title={'center': 'Attr32'}>],
#        [<Axes: title={'center': 'Attr33'}>,
#         <Axes: title={'center': 'Attr34'}>,
#         <Axes: title={'center': 'Attr35'}>,
#         <Axes: title={'center': 'Attr36'}>,
#         <Axes: title={'center': 'Attr37'}>,
#         <Axes: title={'center': 'Attr38'}>,
#         <Axes: title={'center': 'Attr39'}>,
#         <Axes: title={'center': 'Attr40'}>],
#        [<Axes: title={'center': 'Attr41'}>,
#         <Axes: title={'center': 'Attr42'}>,
#         <Axes: title={'center': 'Attr43'}>,
#         <Axes: title={'center': 'Attr44'}>,
#         <Axes: title={'center': 'Attr45'}>,
#         <Axes: title={'center': 'Attr46'}>,
#         <Axes: title={'center': 'Attr47'}>,
#         <Axes: title={'center': 'Attr48'}>],
#        [<Axes: title={'center': 'Attr49'}>,
#         <Axes: title={'center': 'Attr50'}>,
#         <Axes: title={'center': 'Attr51'}>,
#         <Axes: title={'center': 'Attr52'}>,
#         <Axes: title={'center': 'Attr53'}>,
#         <Axes: title={'center': 'Attr54'}>,
#         <Axes: title={'center': 'Attr55'}>,
#         <Axes: title={'center': 'Attr56'}>],
#        [<Axes: title={'center': 'Attr57'}>,
#         <Axes: title={'center': 'Attr58'}>,
#         <Axes: title={'center': 'Attr59'}>,
#         <Axes: title={'center': 'Attr60'}>,
#         <Axes: title={'center': 'Attr61'}>,
#         <Axes: title={'center': 'Attr62'}>,
#         <Axes: title={'center': 'Attr63'}>,
#         <Axes: title={'center': 'Attr64'}>]], dtype=object)

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
data['class']= label_encoder.fit_transform(data['class'])

data['class'].unique()
# Out:
# array([0, 1])

# %%
data['class'].value_counts() #verify => SAME AS BEFORE
# Out:
# 0    9277
# 1     515
# Name: class, dtype: int64

# %% [markdown]
# EDA

# %%
total_cells= np.product(data.shape)
total_missing=data.isnull().sum().sum()
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 1.3788335847159376

# %%
import missingno as msno
msno.matrix(data)
# Out:
# <Axes: >

# %%
fig, axe = plt.subplots(figsize=(30,20))
msno.heatmap(data,ax=axe)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(50,60))
pltmv=sns.displot(data=data.isna().melt(value_name="missing"),
            y="variable",hue="missing",
            multiple="fill",height=10,aspect=1)
plt.savefig("visualizing_missing_data_with_barplot.png", dpi=100)

# %% [markdown]
# METHOD 1 Solving -MISSING VALUE

# %%
d1= data.copy()

# %%
data['Attr1'] = data['Attr1'].fillna(data['Attr1'].mode().iloc[0])

# %%
# Assuming 'data' is your DataFrame containing the columns 'Attr1' to 'Attr64'

for i in range(1, 65):  # Assuming the columns are named from 'Attr1' to 'Attr64'
    col_name = f'Attr{i}'
    data[col_name] = data[col_name].fillna(data[col_name].mode().iloc[0])

# %%
data.isna().sum()
# Out:
# Attr1     0
# Attr2     0
# Attr3     0
# Attr4     0
# Attr5     0
#          ..
# Attr61    0
# Attr62    0
# Attr63    0
# Attr64    0
# class     0
# Length: 65, dtype: int64

# %%
d1.describe()
# Out:
#              Attr1        Attr2        Attr3         Attr4         Attr5  \
# count  9791.000000  9791.000000  9791.000000   9749.000000  9.771000e+03
# mean      0.043019     0.596404     0.130959      8.136600  6.465164e+01
# std       0.359321     4.587122     4.559074    290.647281  1.475939e+04
# min     -12.458000     0.000000  -445.910000     -0.045319 -3.794600e+05
# 25%       0.001321     0.263145     0.020377      1.047000 -5.121700e+01
# 50%       0.041364     0.467740     0.199290      1.591800 -5.557600e-02
# 75%       0.111130     0.689255     0.410670      2.880400  5.573200e+01
# max      20.482000   446.910000    22.769000  27146.000000  1.034100e+06
#
#              Attr6        Attr7         Attr8        Attr9       Attr10  ...  \
# count  9791.000000  9791.000000   9773.000000  9792.000000  9791.000000  ...
# mean     -0.059273     0.059446     19.884016     1.882296     0.389040  ...
# std       6.812754     0.533344    698.697015    17.674650     4.590299  ...
# min    -486.820000   -12.458000     -1.848200    -0.032371  -445.910000  ...
# 25%      -0.000578     0.003004      0.428300     1.006675     0.294440  ...
# 50%       0.000000     0.048820      1.088700     1.161300     0.510450  ...
# 75%       0.065322     0.126940      2.691000     1.970225     0.714290  ...
# max     322.200000    38.618000  53209.000000  1704.800000    12.602000  ...
#
#             Attr56       Attr57       Attr58       Attr59         Attr60  \
# count  9771.000000  9791.000000  9776.000000  9791.000000    9178.000000
# mean     -0.992263     0.035022     1.133287     0.856053     118.156064
# std      77.007971     8.945365     8.038201    26.393305    3230.316692
# min   -7522.100000  -597.420000   -30.892000  -284.380000       0.000000
# 25%       0.003121     0.008768     0.885722     0.000000       5.356325
# 50%       0.043679     0.098026     0.958305     0.002129       9.482000
# 75%       0.117170     0.242680     0.996163     0.211790      19.506000
# max     112.020000   226.760000   668.750000  1661.000000  251570.000000
#
#               Attr61        Attr62       Attr63        Attr64        class
# count    9760.000000  9.771000e+03  9749.000000   9561.000000  9792.000000
# mean       25.194430  2.015157e+03     8.660813     35.949619     0.052594
# std      1099.260821  1.171461e+05    60.838202    483.318623     0.223233
# min       -12.656000 -1.496500e+04    -0.024390     -0.000015     0.000000
# 25%         4.267700  4.323400e+01     2.938800      2.012900     0.000000
# 50%         6.283550  7.472900e+01     4.848900      4.041600     0.000000
# 75%         9.938200  1.233450e+02     8.363800      9.413500     0.000000
# max    108000.000000  1.077900e+07  5662.400000  21153.000000     1.000000
#
# [8 rows x 65 columns]

# %%
sns.countplot(x=d1['class'])
plt.title('Target feature - Bankrupt class')
# Out:
# Text(0.5, 1.0, 'Target feature - Bankrupt class')

# %% [markdown]
# There is imbalance in the Target value, we need to oversample it based

# %% [markdown]
# OverSamppling :SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
from imblearn.over_sampling import SMOTE
import pandas as pd

# Assuming 'data' is your DataFrame with 'Attr1' to 'Attr64' and 'Target' column
X = data.drop('class', axis=1)
y = data['class']

# Initialize the SMOTE object
smote = SMOTE()

# Perform SMOTE oversampling
X_resampled, y_resampled = smote.fit_resample(X, y)

# Combine the resampled features and target back into a DataFrame
resampled_data = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='class')], axis=1)

# %%
X=d1.drop(labels=['class'], axis=1)
y=d1['class']

# %%
from sklearn.impute import SimpleImputer
# Assuming 'data' is your DataFrame with 'Attr1' to 'Attr64' and 'Target' column
X = data.drop('class', axis=1)
y = data['class']

# Step 1: Handle missing values using SimpleImputer
imputer = SimpleImputer(strategy='mean')  # You can choose different imputation strategies based on your data
X_imputed = imputer.fit_transform(X)

# Step 2: Apply SMOTE to oversample the target variable
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X_imputed, y)

# Combine the resampled features and target back into a DataFrame
resampled_data = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='class')], axis=1)

# %%
oversample = SMOTE()
X,y=oversample.fit_resample(X,y)

# %%
sns.countplot(x=y)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
data_x= pd.DataFrame(X,columns=data_keys[:len(data_keys)-1])
print(data_x.head())
#y class data
data_x.shape
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5     Attr6     Attr7    Attr8  \
# 0  0.159290  0.46240  0.07773  1.1683  -44.853  0.467020  0.189480  0.82895
# 1 -0.127430  0.46243  0.26917  1.7517    7.597  0.000925 -0.127430  1.16250
# 2  0.070488  0.23570  0.52781  3.2393  125.680  0.163670  0.086895  2.87180
# 3  0.136760  0.40538  0.31543  1.8705   19.115  0.504970  0.136760  1.45390
# 4 -0.110080  0.69793  0.18878  1.2713  -15.344  0.000000 -0.110080  0.43282
#
#     Attr9   Attr10  ...   Attr55    Attr56   Attr57   Attr58    Attr59  \
# 0  1.1223  0.38330  ...  90533.0  0.108990  0.41557  0.89101  0.001422
# 1  1.2944  0.53757  ...   2624.9 -0.089372 -0.23704  1.06250  0.150410
# 2  1.0574  0.67689  ...  24672.0  0.054286  0.10413  0.94571  0.000000
# 3  1.1144  0.58938  ...   6649.9  0.102630  0.23203  0.89737  0.073024
# 4  1.7350  0.30207  ...   1314.0  0.439880 -0.36440  0.57153  0.000000
#
#     Attr60  Attr61   Attr62  Attr63   Attr64
# 0   7.7928  4.9914  119.810  3.0465   3.0560
# 1   5.4327  3.4629  100.970  3.6150   3.4725
# 2   7.1070  3.3808   76.076  4.7978   4.7818
# 3   6.1384  4.2241   88.299  4.1337   4.6484
# 4  18.8010  2.7925  146.390  2.4934  15.0360
#
# [5 rows x 64 columns]
# (18554, 64)

# %%
data.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5     Attr6     Attr7    Attr8  \
# 0  0.159290  0.46240  0.07773  1.1683  -44.853  0.467020  0.189480  0.82895
# 1 -0.127430  0.46243  0.26917  1.7517    7.597  0.000925 -0.127430  1.16250
# 2  0.070488  0.23570  0.52781  3.2393  125.680  0.163670  0.086895  2.87180
# 3  0.136760  0.40538  0.31543  1.8705   19.115  0.504970  0.136760  1.45390
# 4 -0.110080  0.69793  0.18878  1.2713  -15.344  0.000000 -0.110080  0.43282
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59   Attr60  \
# 0  1.1223  0.38330  ...  0.108990  0.41557  0.89101  0.001422   7.7928
# 1  1.2944  0.53757  ... -0.089372 -0.23704  1.06250  0.150410   5.4327
# 2  1.0574  0.67689  ...  0.054286  0.10413  0.94571  0.000000   7.1070
# 3  1.1144  0.58938  ...  0.102630  0.23203  0.89737  0.073024   6.1384
# 4  1.7350  0.30207  ...  0.439880 -0.36440  0.57153  0.000000  18.8010
#
#    Attr61   Attr62  Attr63   Attr64  class
# 0  4.9914  119.810  3.0465   3.0560      0
# 1  3.4629  100.970  3.6150   3.4725      0
# 2  3.3808   76.076  4.7978   4.7818      0
# 3  4.2241   88.299  4.1337   4.6484      0
# 4  2.7925  146.390  2.4934  15.0360      0
#
# [5 rows x 65 columns]

# %%
data.isna().sum()
# Out:
# Attr1     0
# Attr2     0
# Attr3     0
# Attr4     0
# Attr5     0
#          ..
# Attr61    0
# Attr62    0
# Attr63    0
# Attr64    0
# class     0
# Length: 65, dtype: int64

# %% [markdown]
# Outlier Detection

# %%
for i in data:
    sns.boxplot(x=data[i])
    plt.show()

# %% [markdown]
# treating of outliers may tend to loss of huge amount of data from the dataset

# %% [markdown]
# Scaling

# %%
from sklearn.preprocessing import minmax_scale

# %%
data = np.random.exponential(size=1000)

# %%
scaled_data = minmax_scale(data)

# %%
fig,ax = plt.subplots(1,2)
sns.distplot(data, ax= ax[0])
ax[0].set_title('data')
sns.distplot(scaled_data, ax= ax[1])
ax[1].set_title('Scaled Data')
# Out:
# <ipython-input-41-5590d0fdf95e>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data, ax= ax[0])
# <ipython-input-41-5590d0fdf95e>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(scaled_data, ax= ax[1])
# Text(0.5, 1.0, 'Scaled Data')

# %% [markdown]
# Normalization

# %%
from scipy import stats
from scipy.stats import boxcox

# %%
normalized_data=stats.boxcox(data)
fig, ax=plt.subplots(1,2)
sns.distplot(data,ax= ax[0])
ax[0].set_title('data')
sns.distplot(normalized_data[0], ax= ax[1])
ax[1].set_title('Normalized_data')
# Out:
# <ipython-input-43-c7eb294a7342>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax= ax[0])
# <ipython-input-43-c7eb294a7342>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normalized_data[0], ax= ax[1])
# Text(0.5, 1.0, 'Normalized_data')
