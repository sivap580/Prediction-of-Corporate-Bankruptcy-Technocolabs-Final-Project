# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import the Libraries
from scipy.io import arff
import pandas as pd

#Load the data using "arff.loadarff" then convert it to dataframe
data = arff.loadarff('/content/2year.arff')
data = pd.DataFrame(data[0])

# %%
data
# Out:
#           Attr1    Attr2     Attr3    Attr4      Attr5     Attr6     Attr7  \
# 0      0.202350  0.46500  0.240380  1.51710  -14.54700  0.510690  0.253660
# 1      0.030073  0.59563  0.186680  1.33820  -37.85900 -0.000319  0.041670
# 2      0.257860  0.29949  0.665190  3.22110   71.79900  0.000000  0.318770
# 3      0.227160  0.67850  0.042784  1.08280  -88.21200  0.000000  0.285050
# 4      0.085443  0.38039  0.359230  1.94440   21.73100  0.187900  0.108230
# ...         ...      ...       ...      ...        ...       ...       ...
# 10168  0.029970  0.66806  0.066243  1.11030 -105.55000  0.029970  0.038888
# 10169  0.012843  0.49306 -0.160620  0.61898  -24.80100  0.012843  0.012843
# 10170  0.015092  0.55759 -0.284600  0.48599  -85.57100  0.015092  0.009826
# 10171 -0.002554  0.47076  0.424010  1.90070    0.95483 -0.002554  0.001785
# 10172  0.002072  0.94315 -0.134740  0.85607 -119.92000  0.015226  0.002072
#
#           Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58  \
# 0      0.918160  1.15190  0.426950  ...  0.131840  0.473950  0.86816
# 1      0.678900  0.32356  0.404370  ...  0.121460  0.074369  0.87235
# 2      2.332000  1.67620  0.698410  ...  0.164990  0.369210  0.81614
# 3      0.473840  1.32410  0.321500  ...  0.293580  0.706570  0.78617
# 4      1.371400  1.11260  0.521670  ...  0.101240  0.163790  0.89876
# ...         ...      ...       ...  ...       ...       ...      ...
# 10168  0.482740  1.02920  0.322500  ...  0.028377  0.092931  0.97162
# 10169  0.905900  1.01450  0.446660  ...  0.014247  0.028752  0.98575
# 10170  0.694880  1.00600  0.387460  ...  0.005971  0.038950  0.99403
# 10171  1.114400  0.99293  0.524640  ... -0.007122 -0.004869  1.00710
# 10172  0.059818  1.77490  0.056417  ...  0.031154  0.036720  0.96220
#
#          Attr59   Attr60    Attr61   Attr62   Attr63   Attr64  class
# 0      0.000240   8.5487   5.16550  107.740  3.38790   5.3440   b'0'
# 1      0.000000   1.5264   0.63305  622.660  0.58619   1.2381   b'0'
# 2      0.000000   4.3325   3.19850   65.215  5.59690  47.4660   b'0'
# 3      0.484560   5.2309   5.06750  142.460  2.56210   3.0066   b'0'
# 4      0.000000   5.7035   4.00200   89.058  4.09840   5.9874   b'0'
# ...         ...      ...       ...      ...      ...      ...    ...
# 10168  0.209820   3.0914   3.94560  192.220  1.89880   3.4199   b'1'
# 10169  0.160090  48.6660  63.75200   40.071  9.10870   5.1956   b'1'
# 10170  0.010091  15.0530  11.96400  114.250  3.19480   2.4201   b'1'
# 10171  0.000000   6.4289   5.70250   64.291  5.67730  25.3990   b'1'
# 10172  0.132800   4.1618   4.97340  192.510  1.89600   8.9562   b'1'
#
# [10173 rows x 65 columns]

# %%
data.head()
# Out:
#       Attr1    Attr2     Attr3   Attr4   Attr5     Attr6    Attr7    Attr8  \
# 0  0.202350  0.46500  0.240380  1.5171 -14.547  0.510690  0.25366  0.91816
# 1  0.030073  0.59563  0.186680  1.3382 -37.859 -0.000319  0.04167  0.67890
# 2  0.257860  0.29949  0.665190  3.2211  71.799  0.000000  0.31877  2.33200
# 3  0.227160  0.67850  0.042784  1.0828 -88.212  0.000000  0.28505  0.47384
# 4  0.085443  0.38039  0.359230  1.9444  21.731  0.187900  0.10823  1.37140
#
#      Attr9   Attr10  ...   Attr56    Attr57   Attr58   Attr59  Attr60  \
# 0  1.15190  0.42695  ...  0.13184  0.473950  0.86816  0.00024  8.5487
# 1  0.32356  0.40437  ...  0.12146  0.074369  0.87235  0.00000  1.5264
# 2  1.67620  0.69841  ...  0.16499  0.369210  0.81614  0.00000  4.3325
# 3  1.32410  0.32150  ...  0.29358  0.706570  0.78617  0.48456  5.2309
# 4  1.11260  0.52167  ...  0.10124  0.163790  0.89876  0.00000  5.7035
#
#     Attr61   Attr62   Attr63   Attr64  class
# 0  5.16550  107.740  3.38790   5.3440   b'0'
# 1  0.63305  622.660  0.58619   1.2381   b'0'
# 2  3.19850   65.215  5.59690  47.4660   b'0'
# 3  5.06750  142.460  2.56210   3.0066   b'0'
# 4  4.00200   89.058  4.09840   5.9874   b'0'
#
# [5 rows x 65 columns]

# %%
data.tail()
# Out:
#           Attr1    Attr2     Attr3    Attr4      Attr5     Attr6     Attr7  \
# 10168  0.029970  0.66806  0.066243  1.11030 -105.55000  0.029970  0.038888
# 10169  0.012843  0.49306 -0.160620  0.61898  -24.80100  0.012843  0.012843
# 10170  0.015092  0.55759 -0.284600  0.48599  -85.57100  0.015092  0.009826
# 10171 -0.002554  0.47076  0.424010  1.90070    0.95483 -0.002554  0.001785
# 10172  0.002072  0.94315 -0.134740  0.85607 -119.92000  0.015226  0.002072
#
#           Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58  \
# 10168  0.482740  1.02920  0.322500  ...  0.028377  0.092931  0.97162
# 10169  0.905900  1.01450  0.446660  ...  0.014247  0.028752  0.98575
# 10170  0.694880  1.00600  0.387460  ...  0.005971  0.038950  0.99403
# 10171  1.114400  0.99293  0.524640  ... -0.007122 -0.004869  1.00710
# 10172  0.059818  1.77490  0.056417  ...  0.031154  0.036720  0.96220
#
#          Attr59   Attr60   Attr61   Attr62  Attr63   Attr64  class
# 10168  0.209820   3.0914   3.9456  192.220  1.8988   3.4199   b'1'
# 10169  0.160090  48.6660  63.7520   40.071  9.1087   5.1956   b'1'
# 10170  0.010091  15.0530  11.9640  114.250  3.1948   2.4201   b'1'
# 10171  0.000000   6.4289   5.7025   64.291  5.6773  25.3990   b'1'
# 10172  0.132800   4.1618   4.9734  192.510  1.8960   8.9562   b'1'
#
# [5 rows x 65 columns]

# %%
data_keys= list(data.keys())
len(data_keys)
# Out:
# 65

# %%
print(data.shape)
# Out:
# (10173, 65)

# %%
data.describe()
# Out:
#               Attr1         Attr2         Attr3         Attr4          Attr5  \
# count  10172.000000  10172.000000  10172.000000  10151.000000   10149.000000
# mean       0.043074      0.646960      0.070861      4.144058    -144.830797
# std        1.112028      6.615405      6.606495     51.715242    7811.976260
# min      -75.331000      0.000000   -479.960000      0.002079 -438250.000000
# 25%        0.000364      0.277695      0.012114      1.029200     -50.131000
# 50%        0.049493      0.487335      0.189695      1.524400      -1.907500
# 75%        0.141105      0.705040      0.400400      2.741100      51.443000
# max        7.372700    480.960000      5.502200   4881.600000   70686.000000
#
#               Attr6         Attr7         Attr8         Attr9        Attr10  \
# count  10172.000000  10172.000000  10155.000000  10169.000000  10172.000000
# mean      -0.111564      0.122101      9.868798      2.867541      0.344341
# std        6.568088      6.532490    288.386870     96.674595      6.655844
# min     -508.410000    -75.331000     -1.594500     -0.612590   -479.910000
# 25%        0.000000      0.001975      0.393635      1.026300      0.277365
# 50%        0.000000      0.060057      1.005400      1.285700      0.490925
# 75%        0.074739      0.165865      2.518850      2.256600      0.703280
# max       35.551000    649.230000  18554.000000   9742.300000     74.434000
#
#        ...        Attr55        Attr56        Attr57        Attr58  \
# count  ...  1.017200e+04  10110.000000  10171.000000  10134.000000
# mean   ...  6.080925e+03     -1.128949     -0.043519     12.656337
# std    ...  6.598007e+04     86.502920     12.251651    632.937400
# min    ... -1.805200e+06  -8534.600000   -979.250000     -4.549700
# 25%    ...  5.699975e+00      0.010381      0.009959      0.872130
# 50%    ...  8.326700e+02      0.055013      0.126210      0.949715
# 75%    ...  4.020250e+03      0.134068      0.309135      0.993390
# max    ...  3.657400e+06     20.200000    147.190000  59672.000000
#
#              Attr59         Attr60        Attr61        Attr62        Attr63  \
# count  10171.000000    9630.000000  10157.000000  1.011000e+04  10151.000000
# mean       3.034738     375.332514     16.884020  8.910799e+02     11.217653
# std      238.185655   12294.315980    295.762312  4.366133e+04    233.919213
# min     -189.580000       0.000000     -0.007521 -9.921400e+02     -0.367890
# 25%        0.000000       5.684275      4.695300  4.028225e+01      3.102200
# 50%        0.004849      10.353500      6.988600  6.964550e+01      5.198900
# 75%        0.249240      22.163500     11.073000  1.163200e+02      9.012550
# max    23853.000000  639940.000000  26862.000000  4.144800e+06  23454.000000
#
#               Attr64
# count    9961.000000
# mean       55.275877
# std      1526.588333
# min    -10677.000000
# 25%         2.310900
# 50%         4.536000
# 75%        10.604000
# max    127680.000000
#
# [8 rows x 64 columns]

# %%
data.describe().transpose()
# Out:
#           count        mean           std            min        25%  \
# Attr1   10172.0    0.043074      1.112028     -75.331000   0.000364
# Attr2   10172.0    0.646960      6.615405       0.000000   0.277695
# Attr3   10172.0    0.070861      6.606495    -479.960000   0.012114
# Attr4   10151.0    4.144058     51.715242       0.002079   1.029200
# Attr5   10149.0 -144.830797   7811.976260 -438250.000000 -50.131000
# ...         ...         ...           ...            ...        ...
# Attr60   9630.0  375.332514  12294.315980       0.000000   5.684275
# Attr61  10157.0   16.884020    295.762312      -0.007521   4.695300
# Attr62  10110.0  891.079947  43661.334983    -992.140000  40.282250
# Attr63  10151.0   11.217653    233.919213      -0.367890   3.102200
# Attr64   9961.0   55.275877   1526.588333  -10677.000000   2.310900
#
#               50%         75%           max
# Attr1    0.049493    0.141105  7.372700e+00
# Attr2    0.487335    0.705040  4.809600e+02
# Attr3    0.189695    0.400400  5.502200e+00
# Attr4    1.524400    2.741100  4.881600e+03
# Attr5   -1.907500   51.443000  7.068600e+04
# ...           ...         ...           ...
# Attr60  10.353500   22.163500  6.399400e+05
# Attr61   6.988600   11.073000  2.686200e+04
# Attr62  69.645500  116.320000  4.144800e+06
# Attr63   5.198900    9.012550  2.345400e+04
# Attr64   4.536000   10.604000  1.276800e+05
#
# [64 rows x 8 columns]

# %%
data.corr()
# Out:
# <ipython-input-10-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#            Attr1     Attr2     Attr3     Attr4     Attr5     Attr6     Attr7  \
# Attr1   1.000000 -0.429079  0.428541  0.002925  0.230805  0.332117  0.174900
# Attr2  -0.429079  1.000000 -0.998605 -0.005200 -0.426259 -0.981243 -0.073439
# Attr3   0.428541 -0.998605  1.000000  0.006087  0.427277  0.979942  0.073576
# Attr4   0.002925 -0.005200  0.006087  1.000000  0.028134  0.001466  0.000066
# Attr5   0.230805 -0.426259  0.427277  0.028134  1.000000  0.405971  0.039495
# ...          ...       ...       ...       ...       ...       ...       ...
# Attr60  0.006782 -0.001273  0.001327  0.001662  0.000844 -0.000114  0.522288
# Attr61  0.002783  0.000863 -0.001734 -0.000695 -0.001459 -0.002639  0.408680
# Attr62 -0.001080  0.195149 -0.195482 -0.003101 -0.069180 -0.205424 -0.000437
# Attr63  0.008546 -0.002190  0.002438  0.015307  0.001075  0.000454  0.983337
# Attr64 -0.104515 -0.002082  0.005369 -0.000568  0.000554  0.488089  0.456816
#
#            Attr8     Attr9    Attr10  ...    Attr55    Attr56    Attr57  \
# Attr1   0.000758 -0.009055  0.423049  ...  0.010285  0.000855  0.028875
# Attr2  -0.003174  0.005915 -0.993925  ... -0.008901 -0.000764 -0.000749
# Attr3   0.001938 -0.005595  0.992480  ...  0.009779  0.000320  0.000736
# Attr4   0.259952 -0.000906  0.005288  ...  0.003614  0.000744  0.000809
# Attr5   0.018950 -0.000755  0.424076  ...  0.008601  0.000277 -0.001049
# ...          ...       ...       ...  ...       ...       ...       ...
# Attr60  0.000287  0.524557  0.001246  ... -0.001363  0.000339  0.000901
# Attr61 -0.000914  0.412891 -0.000812  ... -0.002812  0.000792  0.001155
# Attr62 -0.000256 -0.000562 -0.193931  ... -0.003150 -0.210122 -0.000028
# Attr63  0.004023  0.994254  0.002239  ... -0.000154  0.000682  0.001406
# Attr64 -0.001331  0.470965  0.710755  ... -0.001334  0.000508  0.000919
#
#           Attr58    Attr59    Attr60    Attr61    Attr62    Attr63    Attr64
# Attr1  -0.023878 -0.000583  0.006782  0.002783 -0.001080  0.008546 -0.104515
# Attr2   0.001364  0.000614 -0.001273  0.000863  0.195149 -0.002190 -0.002082
# Attr3  -0.000677 -0.000091  0.001327 -0.001734 -0.195482  0.002438  0.005369
# Attr4   0.000920 -0.000717  0.001662 -0.000695 -0.003101  0.015307 -0.000568
# Attr5  -0.000991  0.000219  0.000844 -0.001459 -0.069180  0.001075  0.000554
# ...          ...       ...       ...       ...       ...       ...       ...
# Attr60 -0.000503 -0.000378  1.000000  0.216442 -0.000795  0.522968  0.242183
# Attr61 -0.001060 -0.000503  0.216442  1.000000 -0.001066  0.411375  0.348528
# Attr62  0.210252 -0.000131 -0.000795 -0.001066  1.000000 -0.000946 -0.000617
# Attr63 -0.000882 -0.000432  0.522968  0.411375 -0.000946  1.000000  0.842382
# Attr64 -0.000834 -0.000461  0.242183  0.348528 -0.000617  0.842382  1.000000
#
# [64 rows x 64 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10173 entries, 0 to 10172
# Data columns (total 65 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Attr1   10172 non-null  float64
#  1   Attr2   10172 non-null  float64
#  2   Attr3   10172 non-null  float64
#  3   Attr4   10151 non-null  float64
#  4   Attr5   10149 non-null  float64
#  5   Attr6   10172 non-null  float64
#  6   Attr7   10172 non-null  float64
#  7   Attr8   10155 non-null  float64
#  8   Attr9   10169 non-null  float64
#  9   Attr10  10172 non-null  float64
#  10  Attr11  10172 non-null  float64
#  11  Attr12  10151 non-null  float64
#  12  Attr13  10110 non-null  float64
#  13  Attr14  10172 non-null  float64
#  14  Attr15  10161 non-null  float64
#  15  Attr16  10154 non-null  float64
#  16  Attr17  10155 non-null  float64
#  17  Attr18  10172 non-null  float64
#  18  Attr19  10109 non-null  float64
#  19  Attr20  10110 non-null  float64
#  20  Attr21  7009 non-null   float64
#  21  Attr22  10172 non-null  float64
#  22  Attr23  10110 non-null  float64
#  23  Attr24  9948 non-null   float64
#  24  Attr25  10172 non-null  float64
#  25  Attr26  10154 non-null  float64
#  26  Attr27  9467 non-null   float64
#  27  Attr28  9961 non-null   float64
#  28  Attr29  10172 non-null  float64
#  29  Attr30  10110 non-null  float64
#  30  Attr31  10110 non-null  float64
#  31  Attr32  10086 non-null  float64
#  32  Attr33  10151 non-null  float64
#  33  Attr34  10155 non-null  float64
#  34  Attr35  10172 non-null  float64
#  35  Attr36  10172 non-null  float64
#  36  Attr37  5655 non-null   float64
#  37  Attr38  10172 non-null  float64
#  38  Attr39  10110 non-null  float64
#  39  Attr40  10151 non-null  float64
#  40  Attr41  9976 non-null   float64
#  41  Attr42  10110 non-null  float64
#  42  Attr43  10110 non-null  float64
#  43  Attr44  10110 non-null  float64
#  44  Attr45  9632 non-null   float64
#  45  Attr46  10151 non-null  float64
#  46  Attr47  10099 non-null  float64
#  47  Attr48  10171 non-null  float64
#  48  Attr49  10110 non-null  float64
#  49  Attr50  10155 non-null  float64
#  50  Attr51  10172 non-null  float64
#  51  Attr52  10099 non-null  float64
#  52  Attr53  9961 non-null   float64
#  53  Attr54  9961 non-null   float64
#  54  Attr55  10172 non-null  float64
#  55  Attr56  10110 non-null  float64
#  56  Attr57  10171 non-null  float64
#  57  Attr58  10134 non-null  float64
#  58  Attr59  10171 non-null  float64
#  59  Attr60  9630 non-null   float64
#  60  Attr61  10157 non-null  float64
#  61  Attr62  10110 non-null  float64
#  62  Attr63  10151 non-null  float64
#  63  Attr64  9961 non-null   float64
#  64  class   10173 non-null  object
# dtypes: float64(64), object(1)
# memory usage: 5.0+ MB

# %%
data.columns
# Out:
# Index(['Attr1', 'Attr2', 'Attr3', 'Attr4', 'Attr5', 'Attr6', 'Attr7', 'Attr8',
#        'Attr9', 'Attr10', 'Attr11', 'Attr12', 'Attr13', 'Attr14', 'Attr15',
#        'Attr16', 'Attr17', 'Attr18', 'Attr19', 'Attr20', 'Attr21', 'Attr22',
#        'Attr23', 'Attr24', 'Attr25', 'Attr26', 'Attr27', 'Attr28', 'Attr29',
#        'Attr30', 'Attr31', 'Attr32', 'Attr33', 'Attr34', 'Attr35', 'Attr36',
#        'Attr37', 'Attr38', 'Attr39', 'Attr40', 'Attr41', 'Attr42', 'Attr43',
#        'Attr44', 'Attr45', 'Attr46', 'Attr47', 'Attr48', 'Attr49', 'Attr50',
#        'Attr51', 'Attr52', 'Attr53', 'Attr54', 'Attr55', 'Attr56', 'Attr57',
#        'Attr58', 'Attr59', 'Attr60', 'Attr61', 'Attr62', 'Attr63', 'Attr64',
#        'class'],
#       dtype='object')

# %%
data['class'].value_counts()
# Out:
# b'0'    9773
# b'1'     400
# Name: class, dtype: int64

# %%
data.isna().sum()
# Out:
# Attr1       1
# Attr2       1
# Attr3       1
# Attr4      22
# Attr5      24
#          ...
# Attr61     16
# Attr62     63
# Attr63     22
# Attr64    212
# class       0
# Length: 65, dtype: int64

# %%
data.hist( figsize=(18,18))
# Out:
# array([[<Axes: title={'center': 'Attr1'}>,
#         <Axes: title={'center': 'Attr2'}>,
#         <Axes: title={'center': 'Attr3'}>,
#         <Axes: title={'center': 'Attr4'}>,
#         <Axes: title={'center': 'Attr5'}>,
#         <Axes: title={'center': 'Attr6'}>,
#         <Axes: title={'center': 'Attr7'}>,
#         <Axes: title={'center': 'Attr8'}>],
#        [<Axes: title={'center': 'Attr9'}>,
#         <Axes: title={'center': 'Attr10'}>,
#         <Axes: title={'center': 'Attr11'}>,
#         <Axes: title={'center': 'Attr12'}>,
#         <Axes: title={'center': 'Attr13'}>,
#         <Axes: title={'center': 'Attr14'}>,
#         <Axes: title={'center': 'Attr15'}>,
#         <Axes: title={'center': 'Attr16'}>],
#        [<Axes: title={'center': 'Attr17'}>,
#         <Axes: title={'center': 'Attr18'}>,
#         <Axes: title={'center': 'Attr19'}>,
#         <Axes: title={'center': 'Attr20'}>,
#         <Axes: title={'center': 'Attr21'}>,
#         <Axes: title={'center': 'Attr22'}>,
#         <Axes: title={'center': 'Attr23'}>,
#         <Axes: title={'center': 'Attr24'}>],
#        [<Axes: title={'center': 'Attr25'}>,
#         <Axes: title={'center': 'Attr26'}>,
#         <Axes: title={'center': 'Attr27'}>,
#         <Axes: title={'center': 'Attr28'}>,
#         <Axes: title={'center': 'Attr29'}>,
#         <Axes: title={'center': 'Attr30'}>,
#         <Axes: title={'center': 'Attr31'}>,
#         <Axes: title={'center': 'Attr32'}>],
#        [<Axes: title={'center': 'Attr33'}>,
#         <Axes: title={'center': 'Attr34'}>,
#         <Axes: title={'center': 'Attr35'}>,
#         <Axes: title={'center': 'Attr36'}>,
#         <Axes: title={'center': 'Attr37'}>,
#         <Axes: title={'center': 'Attr38'}>,
#         <Axes: title={'center': 'Attr39'}>,
#         <Axes: title={'center': 'Attr40'}>],
#        [<Axes: title={'center': 'Attr41'}>,
#         <Axes: title={'center': 'Attr42'}>,
#         <Axes: title={'center': 'Attr43'}>,
#         <Axes: title={'center': 'Attr44'}>,
#         <Axes: title={'center': 'Attr45'}>,
#         <Axes: title={'center': 'Attr46'}>,
#         <Axes: title={'center': 'Attr47'}>,
#         <Axes: title={'center': 'Attr48'}>],
#        [<Axes: title={'center': 'Attr49'}>,
#         <Axes: title={'center': 'Attr50'}>,
#         <Axes: title={'center': 'Attr51'}>,
#         <Axes: title={'center': 'Attr52'}>,
#         <Axes: title={'center': 'Attr53'}>,
#         <Axes: title={'center': 'Attr54'}>,
#         <Axes: title={'center': 'Attr55'}>,
#         <Axes: title={'center': 'Attr56'}>],
#        [<Axes: title={'center': 'Attr57'}>,
#         <Axes: title={'center': 'Attr58'}>,
#         <Axes: title={'center': 'Attr59'}>,
#         <Axes: title={'center': 'Attr60'}>,
#         <Axes: title={'center': 'Attr61'}>,
#         <Axes: title={'center': 'Attr62'}>,
#         <Axes: title={'center': 'Attr63'}>,
#         <Axes: title={'center': 'Attr64'}>]], dtype=object)

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
data['class']= label_encoder.fit_transform(data['class'])

data['class'].unique()
# Out:
# array([0, 1])

# %%
data['class'].value_counts() #verify => SAME AS BEFORE
# Out:
# 0    9773
# 1     400
# Name: class, dtype: int64

# %% [markdown]
# EDA

# %%
total_cells= np.product(data.shape)
total_missing=data.isnull().sum().sum()
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 1.8385016143789366

# %%
import missingno as msno
msno.matrix(data)
# Out:
# <Axes: >

# %%
fig, axe = plt.subplots(figsize=(30,20))
msno.heatmap(data,ax=axe)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(50,60))
pltmv=sns.displot(data=data.isna().melt(value_name="missing"),
            y="variable",hue="missing",
            multiple="fill",height=10,aspect=1)
plt.savefig("visualizing_missing_data_with_barplot.png", dpi=100)

# %% [markdown]
# METHOD 1 Solving -MISSING VALUE

# %%
d1= data.copy()

# %%
data['Attr1'] = data['Attr1'].fillna(data['Attr1'].mode().iloc[0])

# %%
# Assuming 'data' is your DataFrame containing the columns 'Attr1' to 'Attr64'

for i in range(1, 65):  # Assuming the columns are named from 'Attr1' to 'Attr64'
    col_name = f'Attr{i}'
    data[col_name] = data[col_name].fillna(data[col_name].mode().iloc[0])

# %%
data.isna().sum()
# Out:
# Attr1     0
# Attr2     0
# Attr3     0
# Attr4     0
# Attr5     0
#          ..
# Attr61    0
# Attr62    0
# Attr63    0
# Attr64    0
# class     0
# Length: 65, dtype: int64

# %%
d1.describe()
# Out:
#               Attr1         Attr2         Attr3         Attr4          Attr5  \
# count  10172.000000  10172.000000  10172.000000  10151.000000   10149.000000
# mean       0.043074      0.646960      0.070861      4.144058    -144.830797
# std        1.112028      6.615405      6.606495     51.715242    7811.976260
# min      -75.331000      0.000000   -479.960000      0.002079 -438250.000000
# 25%        0.000364      0.277695      0.012114      1.029200     -50.131000
# 50%        0.049493      0.487335      0.189695      1.524400      -1.907500
# 75%        0.141105      0.705040      0.400400      2.741100      51.443000
# max        7.372700    480.960000      5.502200   4881.600000   70686.000000
#
#               Attr6         Attr7         Attr8         Attr9        Attr10  \
# count  10172.000000  10172.000000  10155.000000  10169.000000  10172.000000
# mean      -0.111564      0.122101      9.868798      2.867541      0.344341
# std        6.568088      6.532490    288.386870     96.674595      6.655844
# min     -508.410000    -75.331000     -1.594500     -0.612590   -479.910000
# 25%        0.000000      0.001975      0.393635      1.026300      0.277365
# 50%        0.000000      0.060057      1.005400      1.285700      0.490925
# 75%        0.074739      0.165865      2.518850      2.256600      0.703280
# max       35.551000    649.230000  18554.000000   9742.300000     74.434000
#
#        ...        Attr56        Attr57        Attr58        Attr59  \
# count  ...  10110.000000  10171.000000  10134.000000  10171.000000
# mean   ...     -1.128949     -0.043519     12.656337      3.034738
# std    ...     86.502920     12.251651    632.937400    238.185655
# min    ...  -8534.600000   -979.250000     -4.549700   -189.580000
# 25%    ...      0.010381      0.009959      0.872130      0.000000
# 50%    ...      0.055013      0.126210      0.949715      0.004849
# 75%    ...      0.134068      0.309135      0.993390      0.249240
# max    ...     20.200000    147.190000  59672.000000  23853.000000
#
#               Attr60        Attr61        Attr62        Attr63         Attr64  \
# count    9630.000000  10157.000000  1.011000e+04  10151.000000    9961.000000
# mean      375.332514     16.884020  8.910799e+02     11.217653      55.275877
# std     12294.315980    295.762312  4.366133e+04    233.919213    1526.588333
# min         0.000000     -0.007521 -9.921400e+02     -0.367890  -10677.000000
# 25%         5.684275      4.695300  4.028225e+01      3.102200       2.310900
# 50%        10.353500      6.988600  6.964550e+01      5.198900       4.536000
# 75%        22.163500     11.073000  1.163200e+02      9.012550      10.604000
# max    639940.000000  26862.000000  4.144800e+06  23454.000000  127680.000000
#
#               class
# count  10173.000000
# mean       0.039320
# std        0.194364
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 65 columns]

# %%
sns.countplot(x=d1['class'])
plt.title('Target feature - Bankrupt class')
# Out:
# Text(0.5, 1.0, 'Target feature - Bankrupt class')

# %% [markdown]
# There is imbalance in the Target value, we need to oversample it based

# %% [markdown]
# OverSamppling :SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
from imblearn.over_sampling import SMOTE
import pandas as pd

# Assuming 'data' is your DataFrame with 'Attr1' to 'Attr64' and 'Target' column
X = data.drop('class', axis=1)
y = data['class']

# Initialize the SMOTE object
smote = SMOTE()

# Perform SMOTE oversampling
X_resampled, y_resampled = smote.fit_resample(X, y)

# Combine the resampled features and target back into a DataFrame
resampled_data = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='class')], axis=1)

# %%
X=d1.drop(labels=['class'], axis=1)
y=d1['class']

# %%
from sklearn.impute import SimpleImputer
# Assuming 'data' is your DataFrame with 'Attr1' to 'Attr64' and 'Target' column
X = data.drop('class', axis=1)
y = data['class']

# Step 1: Handle missing values using SimpleImputer
imputer = SimpleImputer(strategy='mean')  # You can choose different imputation strategies based on your data
X_imputed = imputer.fit_transform(X)

# Step 2: Apply SMOTE to oversample the target variable
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X_imputed, y)

# Combine the resampled features and target back into a DataFrame
resampled_data = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='class')], axis=1)

# %%
oversample = SMOTE()
X,y=oversample.fit_resample(X,y)

# %%
sns.countplot(x=y)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
data_x= pd.DataFrame(X,columns=data_keys[:len(data_keys)-1])
print(data_x.head())
#y class data
data_x.shape
# Out:
#       Attr1    Attr2     Attr3   Attr4   Attr5     Attr6    Attr7    Attr8  \
# 0  0.202350  0.46500  0.240380  1.5171 -14.547  0.510690  0.25366  0.91816
# 1  0.030073  0.59563  0.186680  1.3382 -37.859 -0.000319  0.04167  0.67890
# 2  0.257860  0.29949  0.665190  3.2211  71.799  0.000000  0.31877  2.33200
# 3  0.227160  0.67850  0.042784  1.0828 -88.212  0.000000  0.28505  0.47384
# 4  0.085443  0.38039  0.359230  1.9444  21.731  0.187900  0.10823  1.37140
#
#      Attr9   Attr10  ...    Attr55   Attr56    Attr57   Attr58   Attr59  \
# 0  1.15190  0.42695  ...  242500.0  0.13184  0.473950  0.86816  0.00024
# 1  0.32356  0.40437  ...    2179.5  0.12146  0.074369  0.87235  0.00000
# 2  1.67620  0.69841  ...    3668.6  0.16499  0.369210  0.81614  0.00000
# 3  1.32410  0.32150  ...    1273.8  0.29358  0.706570  0.78617  0.48456
# 4  1.11260  0.52167  ...   18209.0  0.10124  0.163790  0.89876  0.00000
#
#    Attr60   Attr61   Attr62   Attr63   Attr64
# 0  8.5487  5.16550  107.740  3.38790   5.3440
# 1  1.5264  0.63305  622.660  0.58619   1.2381
# 2  4.3325  3.19850   65.215  5.59690  47.4660
# 3  5.2309  5.06750  142.460  2.56210   3.0066
# 4  5.7035  4.00200   89.058  4.09840   5.9874
#
# [5 rows x 64 columns]
# (19546, 64)

# %%
data.head()
# Out:
#       Attr1    Attr2     Attr3   Attr4   Attr5     Attr6    Attr7    Attr8  \
# 0  0.202350  0.46500  0.240380  1.5171 -14.547  0.510690  0.25366  0.91816
# 1  0.030073  0.59563  0.186680  1.3382 -37.859 -0.000319  0.04167  0.67890
# 2  0.257860  0.29949  0.665190  3.2211  71.799  0.000000  0.31877  2.33200
# 3  0.227160  0.67850  0.042784  1.0828 -88.212  0.000000  0.28505  0.47384
# 4  0.085443  0.38039  0.359230  1.9444  21.731  0.187900  0.10823  1.37140
#
#      Attr9   Attr10  ...   Attr56    Attr57   Attr58   Attr59  Attr60  \
# 0  1.15190  0.42695  ...  0.13184  0.473950  0.86816  0.00024  8.5487
# 1  0.32356  0.40437  ...  0.12146  0.074369  0.87235  0.00000  1.5264
# 2  1.67620  0.69841  ...  0.16499  0.369210  0.81614  0.00000  4.3325
# 3  1.32410  0.32150  ...  0.29358  0.706570  0.78617  0.48456  5.2309
# 4  1.11260  0.52167  ...  0.10124  0.163790  0.89876  0.00000  5.7035
#
#     Attr61   Attr62   Attr63   Attr64  class
# 0  5.16550  107.740  3.38790   5.3440      0
# 1  0.63305  622.660  0.58619   1.2381      0
# 2  3.19850   65.215  5.59690  47.4660      0
# 3  5.06750  142.460  2.56210   3.0066      0
# 4  4.00200   89.058  4.09840   5.9874      0
#
# [5 rows x 65 columns]

# %%
data.isna().sum()
# Out:
# Attr1     0
# Attr2     0
# Attr3     0
# Attr4     0
# Attr5     0
#          ..
# Attr61    0
# Attr62    0
# Attr63    0
# Attr64    0
# class     0
# Length: 65, dtype: int64

# %% [markdown]
# Outlier Detection

# %%
for i in data:
    sns.boxplot(x=data[i])
    plt.show()

# %% [markdown]
# treating of outliers may tend to loss of huge amount of data from the dataset

# %% [markdown]
# Scaling

# %%
from sklearn.preprocessing import minmax_scale

# %%
data = np.random.exponential(size=1000)

# %%
scaled_data = minmax_scale(data)

# %%
fig,ax = plt.subplots(1,2)
sns.distplot(data, ax= ax[0])
ax[0].set_title('data')
sns.distplot(scaled_data, ax= ax[1])
ax[1].set_title('Scaled Data')
# Out:
# <ipython-input-41-5590d0fdf95e>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data, ax= ax[0])
# <ipython-input-41-5590d0fdf95e>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(scaled_data, ax= ax[1])
# Text(0.5, 1.0, 'Scaled Data')

# %% [markdown]
# Normalization

# %%
from scipy import stats
from scipy.stats import boxcox

# %%
normalized_data=stats.boxcox(data)
fig, ax=plt.subplots(1,2)
sns.distplot(data,ax= ax[0])
ax[0].set_title('data')
sns.distplot(normalized_data[0], ax= ax[1])
ax[1].set_title('Normalized_data')
# Out:
# <ipython-input-43-c7eb294a7342>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,ax= ax[0])
# <ipython-input-43-c7eb294a7342>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(normalized_data[0], ax= ax[1])
# Text(0.5, 1.0, 'Normalized_data')
